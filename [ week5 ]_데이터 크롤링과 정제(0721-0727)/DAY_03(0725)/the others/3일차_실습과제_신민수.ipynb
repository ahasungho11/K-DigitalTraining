# %% [markdown]
# # 크롤링 과제3_2022.07.25
#      - 네이버 증시 정보 크롤링
#
# ### 시가 총액 10위까지의 기업 정보를 크롤링
# - 네이버 금융 웹사이트
#      - https://finance.naver.com/sise/sise_market_sum.naver
# - 크롤링 항목 7개 출력
#      - 종목명, 종목코드, 현재가, 전일가, 시가, 고가, 저가
# - 네이버 웹사이트의 한글 깨짐 문제
#      - requests 라이브러리 사용
# - 왼쪽 “시가 총액” 메뉴에서 상위 10개 기업 정보 크롤링
#      - 시가 총액 url: https://finance.naver.com/sise/sise_market_sum.naver
# - 각 회사별 URL 및 이름을 리스트에 저장
#      - <a	href=“/item/main.naver?code=00590”, class=“title”> 삼성전자 </a>
#
# ### 프로그램 동작
# - 코스피 상위 10개 기업의 URL 및 기업 이름을 리스트에 저장
# - 메뉴에서 선택한 기업의 세부 주식 정보를 화면에 출력
# - 사용자가 -1을 입력할 때 까지 계속 반복함
#
# ### 실행 모습
#      --------------------------------------
#       [	네이버 코스피 상위 10대 기업 목록 ]
#      -------------------------------------
#       [	1]	삼성전자
#       [	2]	LG에너지솔루션
#       [	3]	SK하이닉스
#       [	4]	삼성바이오로직스
#       [	5]	삼성전자우
#       [	6]	NAVER
#       [	7]	현대차
#       [	8]	LG화학
#       [   9]   삼성SDI
#       [  10]	기아
#       주가를 검색할 기업의 번호를 입력하세요(-1:	종료):	1
#       https://finance.naver.com/item/main.naver?code=005930
#       종목명:	삼성전자
#       종목코드:	005930
#       현재가:	61,300
#       전일가:	61,800
#       시가:	61,800
#       고가:	62,200
#       저가:	61,200

# %%
# 모듈 설치 
# requests 라이브러리 사용 : 한글 깨짐 방지

from bs4 import	BeautifulSoup
from selenium import webdriver
import requests

wd	=	webdriver.Chrome('C:\MINSU\chromedriver')

# 주식 넘버 정리 (국내 주가 1~10위 기업)
stock_nums = ['005930','373220','000660','207940','005935','005380','035420','051910','006400','000270']

# 10위 기업 랭킹 순으로 한 기업 주가 사이트 열기
top_ten_list=[]
url_list=[]
for stock_num in stock_nums: 
    naver_stock_url = 'https://finance.naver.com/item/main.naver?code=%s' %stock_num
    wd.get(naver_stock_url)
    url_list.append(naver_stock_url)
    
    html	=	wd.page_source
    soup	=	BeautifulSoup(html,'html.parser')
    
    stock_list = soup.find_all('dl',{'class':'blind'})
    
    for stock_one in stock_list:
        stock_info = stock_one.find_all('dd')
        
        stock_name = (stock_info[1].text).split()[1]
        stock_code = (stock_info[2].text).split()[1]
        stock_present = (stock_info[3].text).split()[1]
        stock_yesterday = (stock_info[4].text).split()[1]
        stock_start = (stock_info[5].text).split()[1]
        stock_high = (stock_info[6].text).split()[1]
        stock_low = (stock_info[8].text).split()[1]

        top_ten_list.append([stock_name,stock_code,stock_present,stock_yesterday,stock_start,stock_high,stock_low])
print(top_ten_list)

# 출력 화면
print('*' * 50)
print('[ 네이버 코스피 상위 10대 기업 목록 ]')
print('*' * 50)
print('[ 1]	삼성전자')
print('[ 2]	LG에너지솔루션')
print('[ 3]	SK하이닉스')
print('[ 4]	삼성바이오로직스')
print('[ 5]	삼성전자우')
print('[ 6]	NAVER')
print('[ 7]	현대차')
print('[ 8]	LG화학')
print('[ 9] 삼성SDI')
print('[10] 기아')
choice = int(input('주가를 검색할 기업의 번호를 입력하세요(-1:	종료):'))
print(f'주가를 검색할 기업의 번호를 입력하세요(-1:	종료): {choice}')
print(url_list[choice-1],end='')
while True:
    if choice == -1:break
    else:
        print(f'''
종목명:	{top_ten_list[choice-1][0]}
종목코드: {top_ten_list[choice-1][1]}
현재가: {top_ten_list[choice-1][2]}
전일가: {top_ten_list[choice-1][3]}
시가: {top_ten_list[choice-1][4]}
고가: {top_ten_list[choice-1][5]}
저가: {top_ten_list[choice-1][6]}
''')

        # 종목코드:	
        # 현재가:	61,300
        # 전일가:	61,800
        # 시가:	61,800
        # 고가:	62,200
        # 저가:	61,200')
# Out:
# C:\Users\ahasu\AppData\Local\Temp\ipykernel_8288\2233501149.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   wd	=	webdriver.Chrome('C:\MINSU\chromedriver')
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\common\service.py:71, in Service.start(self)
#      70     cmd.extend(self.command_line_args())
# ---> 71     self.process = subprocess.Popen(cmd, env=self.env,
#      72                                     close_fds=system() != 'Windows',
#      73                                     stdout=self.log_file,
#      74                                     stderr=self.log_file,
#      75                                     stdin=PIPE,
#      76                                     creationflags=self.creationflags)
#      77 except TypeError:
#
# File C:\ProgramData\Anaconda3\lib\subprocess.py:951, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     948             self.stderr = io.TextIOWrapper(self.stderr,
#     949                     encoding=encoding, errors=errors)
# --> 951     self._execute_child(args, executable, preexec_fn, close_fds,
#     952                         pass_fds, cwd, env,
#     953                         startupinfo, creationflags, shell,
#     954                         p2cread, p2cwrite,
#     955                         c2pread, c2pwrite,
#     956                         errread, errwrite,
#     957                         restore_signals,
#     958                         gid, gids, uid, umask,
#     959                         start_new_session)
#     960 except:
#     961     # Cleanup if the child failed starting.
#
# File C:\ProgramData\Anaconda3\lib\subprocess.py:1420, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    1419 try:
# -> 1420     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1421                              # no special security
#    1422                              None, None,
#    1423                              int(not close_fds),
#    1424                              creationflags,
#    1425                              env,
#    1426                              cwd,
#    1427                              startupinfo)
#    1428 finally:
#    1429     # Child is launched. Close the parent's copy of those pipe
#    1430     # handles that only the child should have open.  You need
#    (...)
#    1433     # pipe will not close when the child process exits and the
#    1434     # ReadFile will hang.
#
# FileNotFoundError: [WinError 2] 지정된 파일을 찾을 수 없습니다
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# Input In [1], in <cell line: 8>()
#       5 from selenium import webdriver
#       6 import requests
# ----> 8 wd	=	webdriver.Chrome('C:\MINSU\chromedriver')
#      10 # 주식 넘버 정리 (국내 주가 1~10위 기업)
#      11 stock_nums = ['005930','373220','000660','207940','005935','005380','035420','051910','006400','000270']
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\chrome\webdriver.py:69, in WebDriver.__init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      66 if not service:
#      67     service = Service(executable_path, port, service_args, service_log_path)
# ---> 69 super().__init__(DesiredCapabilities.CHROME['browserName'], "goog",
#      70                  port, options,
#      71                  service_args, desired_capabilities,
#      72                  service_log_path, service, keep_alive)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\chromium\webdriver.py:89, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, port, options, service_args, desired_capabilities, service_log_path, service, keep_alive)
#      86     raise AttributeError('service cannot be None')
#      88 self.service = service
# ---> 89 self.service.start()
#      91 try:
#      92     super().__init__(
#      93         command_executor=ChromiumRemoteConnection(
#      94             remote_server_addr=self.service.service_url,
#      95             browser_name=browser_name, vendor_prefix=vendor_prefix,
#      96             keep_alive=keep_alive, ignore_proxy=_ignore_proxy),
#      97         options=options)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\common\service.py:81, in Service.start(self)
#      79 except OSError as err:
#      80     if err.errno == errno.ENOENT:
# ---> 81         raise WebDriverException(
#      82             "'{}' executable needs to be in PATH. {}".format(
#      83                 os.path.basename(self.path), self.start_error_message)
#      84         )
#      85     elif err.errno == errno.EACCES:
#      86         raise WebDriverException(
#      87             "'{}' executable may have wrong permissions. {}".format(
#      88                 os.path.basename(self.path), self.start_error_message)
#      89         )
#
# WebDriverException: Message: 'chromedriver' executable needs to be in PATH. Please see https://chromedriver.chromium.org/home
