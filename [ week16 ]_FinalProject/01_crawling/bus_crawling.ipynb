# %%
#웹 페이지 열기
import time
import os
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

import requests
import csv
import urllib.request
import urllib.parse
import re
from bs4 import BeautifulSoup

# %%
dr = webdriver.Chrome('C:/Users/ahasu/Desktop/T3Q_Project/chromedriver.exe') # 크롬 드라이버를 실행하는 명령어를 dr로 지정
dr.get('https://google.co.kr/')  # 드라이버를 통해 url의 웹 페이지를 오픈
time.sleep(1)

xpath_text = '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input'
xpath_button = '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[4]/center/input[1]'
keyword = '버스 내 사고'

dr.find_element(By.XPATH,xpath_text).send_keys(keyword)
dr.find_element(By.XPATH,xpath_button).send_keys(Keys.ENTER)
# Out:
# C:\Users\ahasu\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   """Entry point for launching an IPython kernel.

# %%
html = dr.page_source
soup = BeautifulSoup(html, 'html.parser')
time.sleep(1)
text_list = []

for text in soup.find_all('div', attrs={'class': 'Z26q7c UK95Uc'}):
    text_list.append(text.text)
#     print(text.text[:10])

# %%
# xpath
# //*[@id="botstuff"]/div/div[2]/table/tbody/tr/td[3]/a 
# //*[@id="botstuff"]/div/div[2]/table/tbody/tr/td[4]/a
# //*[@id="botstuff"]/div/div[2]/table/tbody/tr/td[5]/a page 4

# //*[@id="pnnext"]/span[2] next page

# %%
for i in range(2,10):
    xpath_pagenum = f'//*[@id="botstuff"]/div/div[2]/table/tbody/tr/td[{i+1}]/a'
    
    dr.find_element(By.XPATH,xpath_pagenum).send_keys(Keys.ENTER)
    time.sleep(3)
    
    html = dr.page_source
    soup = BeautifulSoup(html, 'html.parser') 
    
    for text in soup.find_all('div', attrs={'class': 'Z26q7c UK95Uc'}):
        text_list.append(text.text)

# %%
len(text_list)
# Out:
# 103

# %%
text_list
# Out:
# ['2022. 1. 19. — 대부분의 버스 내 안전사고는 버스의 움직임에 승객이 부주의하거나 미처 대처하지 못한 상황에서 주로 발생한다. 버스가 운행 중이므로 움직임이 없을 수\xa0...',
#  '버스 승객 사고 보상버스 교통사고버스 접촉사고버스 승객 사고 합의금버스 급정거 사고버스 교통사고 보상함께 검색한 항목',
#  '2021. 1. 6. — 시민들의 안전하고 편리한 이동을 위한 대중교통시설. 그중에서도 버스는 이동 중 사고 발생의 위험이 높은데요. 통계에 따르면 시내버스 교통사고만\xa0...',
#  '버스 승객 사고 보상버스 교통사고버스 접촉사고버스 승객 사고 합의금버스 급정거 사고버스 교통사고 보상함께 검색한 항목',
#  '차내 안전사고는 운전자의 과실이나 부주의로 인해 탑승객이나 동승자가 부상당하는 경우를 말한다. 교통사고는 도로교통법, 교통사고처리특례법, 특정범죄가중처벌등에\xa0...',
#  '버스 승객 사고 보상버스 교통사고버스 접촉사고버스 승객 사고 합의금버스 급정거 사고버스 교통사고 보상함께 검색한 항목',
#  '2021. 12. 1. — 버스 안에서 사고가 났을 땐 전국 시내·시외 버스회사 대부분이 가입한 전국버스공제조합이 주로 보험사 역할을 맡아 승객의 고의 여부와 과실 정도를\xa0...',
#  '버스 승객 사고 보상버스 교통사고버스 접촉사고버스 승객 사고 합의금버스 급정거 사고버스 교통사고 보상함께 검색한 항목',
#  '버스 출퇴근 중 사고, 지하철 출퇴근 중 사고, 대중교통사고 피해보상, 버스공제조합 ... 여객의 안전을 확보하기 위하여 필요한 경우 철도차량 내 여객을 대피시킬 것.',
#  '버스 승객 사고 보상버스 교통사고버스 접촉사고버스 승객 사고 합의금버스 급정거 사고버스 교통사고 보상함께 검색한 항목',
#  "2021. 1. 30. — 한국운수산업연구원에서 낸 '버스 차내 안전사고 감소방안 연구'(2019)에 따르면 2016년부터 2018년 사이 발생한 버스 교통사고 중 승하차 사고는\xa0...",
#  '버스 승객 사고 보상버스 교통사고버스 접촉사고버스 승객 사고 합의금버스 급정거 사고버스 교통사고 보상함께 검색한 항목',
#  '유럽 등 해외 주요 선진국에서는 버스 교통사고가 우리나라의 발생률에 비해 매우 적고, 사망자 또한 거의 발생하지 않는다. 공공이 이용하는 교통수단이므로 안전에\xa0...',
#  '버스 승객 사고 보상버스 교통사고버스 접촉사고버스 승객 사고 합의금버스 급정거 사고버스 교통사고 보상함께 검색한 항목',
#  '2022. 10. 20. — 현재 거론되는 가능성은 운전자 과실이나 이상, 버스결함인데 사고버스에 탑승했던 40대 승객이 버스를 통제하기 위해 운전기사가 노력했다는 증언을\xa0...',
#  '버스 승객 사고 보상버스 교통사고버스 접촉사고버스 승객 사고 합의금버스 급정거 사고버스 교통사고 보상함께 검색한 항목',
#  '임삼진 저술 · 5회 인용 — 버스회사의 사고기록을 이용하여 대중교통체계 개편에 따른 버스사고의 변화를 분석하고, 버. 스사고율 예측모형을 개발하였다. 버스사고 변화패턴을 확인하기 위하여\xa0...페이지 12개',
#  '버스 승객 사고 보상버스 교통사고버스 접촉사고버스 승객 사고 합의금버스 급정거 사고버스 교통사고 보상함께 검색한 항목',
#  '버스 내 승객 사고로 가해자는 버스를 급정거하게 했던 레미콘 차량입니다 버스 신호위반 교통사고, 대인접수를 안해준다고 가해자는 시외고속버스의 운전자이고 저희\xa0...',
#  '택시에 승객으로 탑승 중 상대방 차량과 쌍방과실 버스 내 넘어짐 사고가 발생하면 승객이 버스기사와 합의해 합의금을 피해자 유족은 위 금원을 지급 117%이고 초법\xa0...',
#  '2022. 4. 11. — 버스사고란 버스가 운행 중 발생한 충돌, 탈선, 추락 등에 의하여 다른 교통기관이나 물건, 운전자나 보행자 등이 손괴 또는 사상되는 사고를 뜻한다.',
#  '교통사고: 2차사고 • 가해 • 가해자 • 가해차량 • ...교통: BIS • ITS • UTIS • 감응신호시스템 • 경로 • ...',
#  '이에 시내버스 차내 안전사고의 위해사례 분석을 통하여 문제점을 도출하고 안전사고 예방 및 저감을 위한 개선방안을 제시, 대중교통 활성화에 이바지함.',
#  '2021. 12. 15. — 서울버스공제조합·한국교통안전공단 서울버스 “시내버스 사고 감소” 힘 모아대진여객·도원교통·서울버스 등 3개 회사는 사고감소 최우수 업체 선정\xa0...',
#  'M BHIN 저술 · 2019 · 3회 인용 — 버스운전자의 안전운행을 확보하기 위해서는 운전자 교통사고 원인 등을 분석해 안전운행. 을 지원 할 수 있는 정책이 뒷받침되어야 한다. 따라서 국토교통부는 사업용\xa0...페이지 13개',
#  '2021. 11. 22. — 1,2심은 버스 운행 중 승객 C씨가 부상을 입었다는 사실은 인정했지만, "사고는 버스를 운전한 A씨가 아니라 전적으로 C씨의 과실로 발생했다"며 원고\xa0...',
#  '2022. 7. 29. — 버스 내 안전사고. 작성자 : 이석진. 카테고리, 교통사고 처리/분석. 더운 날씨에 고생들 많으십니까... 저는 고양시에서 버스기사로 근무하는 지체\xa0...',
#  '2021. 2. 1. — 국토교통부(장관 변창흠)는 파주시 시내버스 문 끼임 사고 등 각종 버스안전사고를 예방하기 위하여 금일(2월 1일) 17개 시,도, 버스업계,\xa0...',
#  '분류한 버스 차내 안전사고 데이터 중 텍스트 기반의 사고개요 데이터를 통계분석 패키지 R Project를 활용하여 텍스트 마이닝 분석을 수행하였다. 텍스트 마이닝을\xa0...',
#  '학위구분: 국내석사학위수여기관: 명지대학교 대학원 일반대학원',
#  '2021. 11. 22. — 시내버스 안에서 승객이 넘어져 다쳤다면 피해 승객의 고의성이 증명되지 않는 한 버스 회사에 배상 책임이 있다고 대법원이 판단했다.',
#  '2021. 5. 20. — 버스 내 안전사고는 69.4%, 버스 승하차 도중 사고는 17.6%로 각각 조사됐다. 버스 내 안전사고의 이유는 짧은 배차시간에 따른 과속 운전, 업무 과중\xa0...',
#  '2022. 8. 11. — 버스공제조합 자료에 따르면 지난해 차내 안전사고는 시내버스 전체사고의 약 62.3%를 차지하는 것으로 나타났다. 이에 전북본부는 대중교통 이용문화를\xa0...',
#  '2022. 10. 12. — 뒤를 쫓아가던 동료 버스 운전기사가 고의 사고를 내서 추가 피해를 막았습니다. 양동훈 기자입니다. [기자] 고속도로 갓길에서 중형 버스가 가드레일을\xa0...',
#  '2022. 4. 7. — 본 포스팅은 버스를 포함한 대중교통 이동수단과 관련해서 사고가 ... 내가 버스를 이용할 때 사고가 날 경우 버스공제조합에서 보상을 해줍니다.',
#  'xxxx.xx 「시내버스 차내 안전사고 실태 조사」보고서 소비자안전본부 생활안전팀 목 차 Ⅰ. 조사개요 x x. 배경 및 목적x x. 조사 방법x Ⅱ. 일반현황 x x.',
#  '2018. 1. 29. — 그러나 요즘에는 버스 내 블랙박스가 설치되어 있기 때문에 사고 영상만 확보한다면 상황의 입증은 그렇게 어렵지 않다. 이런 경우 버스 탑승객\xa0...',
#  '사고사례 들여다보기. 통학버스 운행 중 사고 사례와 예방법. 어린이들이 통학버스에서 사고를 당하는 경우는 승차, 하차 시, 그리고 운행 중 사고유형으로 나눠볼 수\xa0...',
#  '2021. 5. 20. — 버스 내 안전사고가 발생하는 것은 과속운행, 짧은 배차시간, 과중한 업무 등이 있었고, 승객이 손잡이를 제대로 잡지 않고 있거나 버스 완전 정차\xa0...',
#  '2021. 5. 24. — 버스는 진로 변경 차량을 보고 급정지했으나 차로를 변경하는 승용차와 충돌하여 버스 내 승객이 부상을 입는 사고가 발생하고 말았다.',
#  '2019. 4. 22. — 차대차 충돌, 차대시설물 충돌, 탑승 중 차량 내 넘어짐, 출입문 끼임, 승객 하차 전 출발로 인한 추락, 승강장 사고, 도로횡단사고 등도 시내버스로\xa0...',
#  '2021. 5. 20. — 부산 시내버스 안전사고 대부분이 승하차 과정이거나 운행 중 내부에서 발생하는 것으로 확인되면서 탑승객들의 안전 인식개선이 필요하다는 지적이\xa0...',
#  '2022. 4. 27. — 내 사건을 의뢰하고, 변호사 제안서 받으세요. (주) 로앤굿. 사업자등록번호: 668-86-01551 | 대표이사: 민명기 | 주소: 서울특별시 강남구 테헤란로83\xa0...',
#  '2021. 3. 2. — 운전기사의 잘못이나 버스 관리 소홀로 승객이 피해를 입으면 버스 회사나 공제조합으로부터 보상이 가능한데요. 버스가 다른 차량과 사고가 나거나\xa0...',
#  '2022. 2. 16. — 서울시가 추진하는 버스, 지하철, 택시, 승용차, 자전거, 보행 , 주차 분야의 정책, 사업, 자료, 최신소식을 공유합니다.',
#  '2021. 4. 11. — [부상사고] 버스내 안전사고. 피해자생년월일. 피해자의 소득 (세금공제전 소득). 피해자 과실 (보험사주장 과실). 피해자진단명/ 수술명/입원기간.',
#  '따라서 교통사고 예방을 위해서는 운전자에 대한 안전관리가 무엇보다 중요하다. 특히 노선버스와 같은 대중교통 수단은 많은 승객이 이용하고, 하루 종일 운행하기\xa0...',
#  '교통사고 통합자료, 도로교통공단 통합DB, 경찰청·손해보험협회·공제조합. 교통사고 원인분석 정보, 지역교통안전계획 수립 및 교통사고 원인조사 보고서\xa0...',
#  '2022. 7. 14. — 어린이보호구역에서 운전자의 부주의 때문에, 혹은 통학버스 승하차 시 ... 하지만 경찰 검토 결과 굴착기는 건설기계로 분류돼 스쿨존 내 사고를\xa0...',
#  '2021. 1. 20. — 시민들의 안전하고 편리한 이동을 위한 대중교통시설. 그중에서도 버스는 이동 중 사고 발생의 위험이 높은데요. 통계에 따르면 시내버스 교통사고만\xa0...',
#  '#Shorts - YouTube 시내버스 교통사고로 내 차가 망가졌을 때 대처 방법! #Shorts - YouTube 시내버스. 판례 -- 교통사고시 버스 승객을 구하려다 그 교통사고로\xa0...',
#  '부천체육관에서 소각장 사거리 방향으로 주행하는 버스가 과속방지턱을 넘어가는 순간 버스 내부에서 승객이 넘어지며 의자 모서리에 머리를 부딪히고 버스사고 공제\xa0...',
#  '안전벨트를 했지만 얼굴을 앞 좌석에 받았구요 버스 내 넘어짐 사고가 발생하면 승객이 버스기사와 합의해 합의금을 휴대전화에는 사고 당시 버스에 타고 있던 승객들\xa0...',
#  '보상은 받을 수 도로교 설계 기준 시내버스 안에서 넘어짐 사고, 과실은 누구에게? 보상은 받을 수. 손해배상 > 손해배상-사례 및 판례 1 페이지 교통사고 상담 - 경기도\xa0...',
#  '2022. 8. 26. — 급정거한 시내버스 안에서 노인 승객이 넘어져 사망한 사고로 버스기사가 1심에서 금고형의 집행유예를 선고 받았다. 26일 법조...',
#  '2021. 11. 4. — 시내버스 등을 탑승했을때, 교통사고가 나면 어떻게 보상을 받는지 정보가 ... 내부 cctv를 보아 사고의 정도와 승객의 과실여부를 따지게 됩니다.',
#  '답변 2개\xa0 · \xa0인기 답변:\xa0안녕하세요? 아하(Aha) 법률 분야 전문가 이영찬 손해사정사입니다.질문하신 ...',
#  '교통사고 주요판례 ; 120, document 버스 승객이 급정거로 인해 버스 안에서 넘어져 뇌진탕 등의 상해를 입은 경우 위 버스에 대한 자동차공제사업자의 책임을 인정한 판결\xa0...',
#  '2022. 8. 11. — 경기도 부천에서 승객 40여명을 태운 광역버스가 승용차와 가로등을 잇따라 들이받아 9명이 중경상을 입는 사고가 발생했다. 이 사고로 승용차 운전자\xa0...',
#  '그래도 교통사고 났을 때, 괜찮다고 먼저 자리를 뜨면 안됨! 부천체육관에서 소각장 사거리 방향으로 주행하는 버스가 과속방지턱을 넘어가는 순간 버스 내부에서 승객\xa0...',
#  '어제 사고버스 승객인데 아파서 병원간다고 하면되나요? 버스 내 넘어짐 사고가 발생하면 승객이 버스기사와 합의해 합의금을 진단서는 아직 안봤지만 경추염좌랑 요추염좌\xa0...',
#  '어제 사고버스 승객인데 아파서 병원간다고 하면되나요? 버스 내 넘어짐 사고가 발생하면 승객이 버스기사와 합의해 합의금을 진단서는 아직 안봤지만 경추염좌랑 요추염좌\xa0...',
#  '입원해서 합의금 받고싶은 생각은 별로 없어서ㅠㅠ 교통사고전문변호사,보험전문변호사, 장슬기 변호사와 손해사정사 · 버스 내 승객 사고로 가해자는 버스를 급정거하게\xa0...',
#  '버스 내 넘어짐 사고가 발생하면 승객이 버스기사와 합의해 합의금을 5일 전 음주사고를 내어 학원버스와 크게 충돌했씁니다 207, 교통사고 · [채권양도]-판례-형사\xa0...',
#  '2014. 4. 4. — 버스기사가 뇌출혈을 일으키는 바람에 버스가 3km가량 경로에서 벗어나 운행되는 아찔한 일도 벌어졌습니다. 사건사고 소식, 박대기 기자입니다.',
#  '버스내 사고 - 버스에서 손잡이를 제대로 잡지 못하여 넘어지게 되면 상황에 따라 10%~20%정도 발생합니다. 갑작스러운 개문발차(문을 열고 출발)로 인한 사고의 경우\xa0...',
#  '2021. 5. 20. — 시내버스와 관련된 안전사고 대다수가 차량 안에서 발생한다는 사실, 아셨습니까? 그런데 정작 사고보상은 회사나 보험사가 아닌 버스기사가 직접 부담\xa0...',
#  '2020. 10. 18. — [시흥타임즈] 경기도 내 2층 버스 운행이 시작된 후 204건의 안전사고가 발생했는데, 82%가 운전자 부주의에 의한 것으로 나타났다.',
#  '버스 내 승객 사고로 가해자는 버스를 급정거하게 했던 레미콘 차량입니다 형사합의, 가해자에서 합의금을 요구하지 말라고 치료비만 준다고 협박 - YouTube [하차\xa0...',
#  "2019. 5. 20. — 미디어파인=손해사정사 윤금옥의 숨은보험금찾기] '사고는 버스운전자가 냈는데 타고 있던 승객이 무슨 잘못이야?'라고 생각할 수도 있겠지만 사실은\xa0...",
#  '교통사고로 내 차가 망가졌을 때 대처 방법! #Shorts - YouTube 시내버스 그리고 또 적절한 합의금은 얼마 정도인지 약 7번의 통원치료만 받았는데 솔직히 it전문직이라 목\xa0...',
#  '오늘 대전역앞에서 버스사고가 있 안전벨트를 했지만 얼굴을 앞 좌석에 받았구요 따라서 경찰서에 사고 접수시 가해자는 형사입건되며, 택시승객이 도로에서 하차중에 발생\xa0...',
#  '질문과 답변 - 버스 승객) 교통사고 합의금에 대해 여쭤봅니다 버스 내 승객 사고로 가해자는 버스를 급정거하게 했던 레미콘 차량입니다 버스를타고 집에 가는도중\xa0...',
#  'W Park 저술 · 2016 · 6회 인용 — 시간적 및 공간적 범위 내에서 신고된 버스 교통사고는. 64,316건이다. 이 중 기타 버스 교통사고 36건을 제외. 하고 업종별로 나누면 시내버스 57,085건, 농어촌버스.',
#  '분명 승객인 내가 피해를 입었지만 합의금은 고사하고 피해 입은 내역에 두 사커 교통사고 합의금 문의 "연락을 안 줍니다 택시 타고 가던 중 사고 교통사고 합의금\xa0...',
#  '2021. 3. 19. — 그렇다면 만약 버스에 타고 있던 승객이 다쳤을 경우 어떤 버스사고보상을 ... 제기한 손해배상 청구 소송에서 원고 일부 승소 판결을 내렸습니다.',
#  '... 합의금은 주변 친구들이 버스공제조합에서 15만원을 준다고 합의후에 병원비가 버스 내 승객 사고로 가해자는 버스를 급정거하게 했던 레미콘 차량입니다 운전자\xa0...',
#  '2021. 5. 20. — (부산=뉴스1) 노경민 기자 = 부산 시내버스와 관련한 사고 중 87%가 버스 안에서 발생하거나 승·하차 도중 일어난 것으로 조사됐다.',
#  '2009. 12. 24. — 시내버스 차내에서 승객이 다치는 안전사고가 지속적으로 발생되고 있어 주의가 요망된다. 한국소비자원(원장 김영신, www.kca.go.kr)은 최근 3년 9\xa0...',
#  '2012. 10. 12. — 한국 소비자원 조사결과에 따르면 버스 안에서 승객들이 다치는 사례는 대부분 운전기사의 부주의 때문이다. 운전기사들의 부주의로 발생한 사고의\xa0...',
#  '2021. 4. 26. — 버스 내 넘어짐 사고. 버스기사로서 승객을 태우고 손잡이 잡은 것을 확인 하고 출발하며 움직이다가 서서히 정차하였는데, 그 때에 승객이 일어났고\xa0...',
#  '답변 1개\xa0 · \xa00표:\xa0최근에 나온 판례는 없으며 위 92도56 판례의 취지가 ‘운전기사가 버스를 급발진시키지 않고 통상적으로 출발시켰다는 ...',
#  '2017. 8. 9. — 여기에는 몇 가지 이유가 있는데요, 우선 버스 사고는 사고 자체의 규모가 크고, 버스에 에어백이나 안전벨트 등 기본적인 안전 장비조차 갖추어져 있지\xa0...',
#  '4시간 전 — 정부는 안전사고 위험 방지를 위해 2014년 광역급행버스, 경기순환버스, 직행좌석버스 등 서울과 경기지역을 잇는 버스의 입석을 금지한 바 있다.',
#  "청구인은 버스에서 하차하다가 사고가 발생하였으므로 '운행중 사고'에 해당하며, ... 사고버스회사측에서 별다른 안전조치를 취하지 않아 미끄러져 넘어진 사고라며\xa0...",
#  '2018. 12. 12. — 버스랑 사고났어. ... 그냥 버스와 비볐다고 했다. ... 심지어 글쓰고있는 내 옆에서 보험사 부르고 경찰 부르고 그다음 순으로 날 불렀단다.',
#  '2020. 3. 13. — 운송 순간에 이 버스를 탈 때 체결하는 운송계약, 그것도 다 계약이니까 계약에서 말하는 승객에 대한 안전·배려 의무가 있을 수도 있고 도로교통법이나\xa0...',
#  '2014. 11. 11. — 진주시 초장동 명신고옆 대로변 시내버스 차고지 옆 도로를 주행하는 시내버스 차량의 무질서한 교통 혼잡으로 인해 교통사고 발생의 위험이 높다.11\xa0...',
#  '2017. 4. 4. — 본 사건 당사자는 ○○여객 마을버스 운전기사로서, 2017년 02월 27일 13:00 평소처럼 버스운행 중 피해자가 자리를 옮기다가 버스내에서 넘어지는 사고를\xa0...',
#  '2019. 6. 13. — 치료를 받는 중 갑자기 말을 바꾸면서 치료비를 못 받게 되서 그로인해 후유증이 남을수 있을것 같아서, 정식 교통사고 절차처럼 버스회사 대인보험처리를\xa0...',
#  '사고일: 2019-06-05피해자 생년월일: 620529형사합의: 가해자에서 합의금을 요구하지 말라고 ...피해자의 직업 소득: 생산직/월급 2,700,000',
#  '2017. 7. 3. — 사고후에 보험 부를려고했는대 기사아저씨가 버스블박있다고 승객있다고 ... 보험처리하겟다고했거든요 느낌이마니 버스아저씨가 ... 내 댓글 보기 |.',
#  "7일 전 — (비전21뉴스) 해솔빛유치원(원장 김미애)은 11월 7일 '어린이 통학버스 안전사고 예방의 날 캠페인'을 실시했다고 밝혔다. 이번 캠페인은 통학 차량을\xa0...",
#  '20시간 전 — GS건설은 메타버스 전문 기업인 벤타브이알과 업무협약을 체결해 건설업과 관련된 위험작업 특별교육, GS건설 필수안전수칙, 사고 유형별 영상 등\xa0...',
#  '20시간 전 — 최근 교내 구성원들의 개인형 이동장치 사용이 증가함에 따라 교내 전동킥보드, 전기자전거와 관련된 사고가 늘어난 것이 그 원인이다.',
#  "23시간 전 — [매일일보 권영현 기자] 동국대학교가 메타버스를 활용한 '2022학년도 ... 중앙도서관 로비와 IF Zone 등을 구현한 메타버스 내에서는 이용자가 사서\xa0...",
#  '16시간 전 — 제주도내 버스의 모습. (사진=제주투데이 DB). 제주도가 최근 제4차 대중교통계획을 발표한 가운데, 월정액 무제한 버스 이용권 제도를 도입해야\xa0...',
#  '53분 전 — 교통사고 발생이 많은 11월을 맞아 진행되는 이번 캠페인은 안전한 등굣길 ... 또한 안전신문고 앱을 통한 횡단보도·소화전·버스정류소·교차로모퉁이·\xa0...',
#  '17시간 전 — 최 시장은 △내부 순환도로 비알티(BRT) 버스 요금 할인 △생활권 ... 전체 교통사고 중 자전거 비율이 전국 평균을 넘어서고 있다는 진단에서다.',
#  '13시간 전 — 반면 지난달 29일 이태원 참사를 계기로 버스 과밀에 대한 안전성 문제가 대두되면서 업체들이 안전 강화 차원에서 입석 중단을 결정했다. 18일부터 절반\xa0...',
#  '5시간 전 — 서울버스광고/서울시내버스광고 전문 업체입니다. ... 속초시 노학동 한 테마파크 주차장에서 초등학생 A양이 버스에 치여 숨지는 사고가 발생했다.',
#  '53분 전 — 교통사고 발생이 많은 11월을 맞아 진행되는 이번 캠페인은 안전한 등굣길 ... 또한 안전신문고 앱을 통한 횡단보도·소화전·버스정류소·교차로모퉁이·\xa0...',
#  '14시간 전 — 오 의원, 시내버스 교통사고 높은 지역에 대한 특별관리 방안 마련 촉구 ... 시내버스 교통사고율에 따른 특별관리 및 개인·단체가 운영하는 교통안전\xa0...']

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
from konlpy.tag import Okt
from PIL import Image
import numpy as np

# %%
result = ' '.join(s for s in text_list)

# %%
result
# Out:
# '2022. 1. 19. — 대부분의 버스 내 안전사고는 버스의 움직임에 승객이 부주의하거나 미처 대처하지 못한 상황에서 주로 발생한다. 버스가 운행 중이므로 움직임이 없을 수\xa0... 버스 승객 사고 보상버스 교통사고버스 접촉사고버스 승객 사고 합의금버스 급정거 사고버스 교통사고 보상함께 검색한 항목 2021. 1. 6. — 시민들의 안전하고 편리한 이동을 위한 대중교통시설. 그중에서도 버스는 이동 중 사고 발생의 위험이 높은데요. 통계에 따르면 시내버스 교통사고만\xa0... 버스 승객 사고 보상버스 교통사고버스 접촉사고버스 승객 사고 합의금버스 급정거 사고버스 교통사고 보상함께 검색한 항목 차내 안전사고는 운전자의 과실이나 부주의로 인해 탑승객이나 동승자가 부상당하는 경우를 말한다. 교통사고는 도로교통법, 교통사고처리특례법, 특정범죄가중처벌등에\xa0... 버스 승객 사고 보상버스 교통사고버스 접촉사고버스 승객 사고 합의금버스 급정거 사고버스 교통사고 보상함께 검색한 항목 2021. 12. 1. — 버스 안에서 사고가 났을 땐 전국 시내·시외 버스회사 대부분이 가입한 전국버스공제조합이 주로 보험사 역할을 맡아 승객의 고의 여부와 과실 정도를\xa0... 버스 승객 사고 보상버스 교통사고버스 접촉사고버스 승객 사고 합의금버스 급정거 사고버스 교통사고 보상함께 검색한 항목 버스 출퇴근 중 사고, 지하철 출퇴근 중 사고, 대중교통사고 피해보상, 버스공제조합 ... 여객의 안전을 확보하기 위하여 필요한 경우 철도차량 내 여객을 대피시킬 것. 버스 승객 사고 보상버스 교통사고버스 접촉사고버스 승객 사고 합의금버스 급정거 사고버스 교통사고 보상함께 검색한 항목 2021. 1. 30. — 한국운수산업연구원에서 낸 \'버스 차내 안전사고 감소방안 연구\'(2019)에 따르면 2016년부터 2018년 사이 발생한 버스 교통사고 중 승하차 사고는\xa0... 버스 승객 사고 보상버스 교통사고버스 접촉사고버스 승객 사고 합의금버스 급정거 사고버스 교통사고 보상함께 검색한 항목 유럽 등 해외 주요 선진국에서는 버스 교통사고가 우리나라의 발생률에 비해 매우 적고, 사망자 또한 거의 발생하지 않는다. 공공이 이용하는 교통수단이므로 안전에\xa0... 버스 승객 사고 보상버스 교통사고버스 접촉사고버스 승객 사고 합의금버스 급정거 사고버스 교통사고 보상함께 검색한 항목 2022. 10. 20. — 현재 거론되는 가능성은 운전자 과실이나 이상, 버스결함인데 사고버스에 탑승했던 40대 승객이 버스를 통제하기 위해 운전기사가 노력했다는 증언을\xa0... 버스 승객 사고 보상버스 교통사고버스 접촉사고버스 승객 사고 합의금버스 급정거 사고버스 교통사고 보상함께 검색한 항목 임삼진 저술 · 5회 인용 — 버스회사의 사고기록을 이용하여 대중교통체계 개편에 따른 버스사고의 변화를 분석하고, 버. 스사고율 예측모형을 개발하였다. 버스사고 변화패턴을 확인하기 위하여\xa0...페이지 12개 버스 승객 사고 보상버스 교통사고버스 접촉사고버스 승객 사고 합의금버스 급정거 사고버스 교통사고 보상함께 검색한 항목 버스 내 승객 사고로 가해자는 버스를 급정거하게 했던 레미콘 차량입니다 버스 신호위반 교통사고, 대인접수를 안해준다고 가해자는 시외고속버스의 운전자이고 저희\xa0... 택시에 승객으로 탑승 중 상대방 차량과 쌍방과실 버스 내 넘어짐 사고가 발생하면 승객이 버스기사와 합의해 합의금을 피해자 유족은 위 금원을 지급 117%이고 초법\xa0... 2022. 4. 11. — 버스사고란 버스가 운행 중 발생한 충돌, 탈선, 추락 등에 의하여 다른 교통기관이나 물건, 운전자나 보행자 등이 손괴 또는 사상되는 사고를 뜻한다. 교통사고: 2차사고 • 가해 • 가해자 • 가해차량 • ...교통: BIS • ITS • UTIS • 감응신호시스템 • 경로 • ... 이에 시내버스 차내 안전사고의 위해사례 분석을 통하여 문제점을 도출하고 안전사고 예방 및 저감을 위한 개선방안을 제시, 대중교통 활성화에 이바지함. 2021. 12. 15. — 서울버스공제조합·한국교통안전공단 서울버스 “시내버스 사고 감소” 힘 모아대진여객·도원교통·서울버스 등 3개 회사는 사고감소 최우수 업체 선정\xa0... M BHIN 저술 · 2019 · 3회 인용 — 버스운전자의 안전운행을 확보하기 위해서는 운전자 교통사고 원인 등을 분석해 안전운행. 을 지원 할 수 있는 정책이 뒷받침되어야 한다. 따라서 국토교통부는 사업용\xa0...페이지 13개 2021. 11. 22. — 1,2심은 버스 운행 중 승객 C씨가 부상을 입었다는 사실은 인정했지만, "사고는 버스를 운전한 A씨가 아니라 전적으로 C씨의 과실로 발생했다"며 원고\xa0... 2022. 7. 29. — 버스 내 안전사고. 작성자 : 이석진. 카테고리, 교통사고 처리/분석. 더운 날씨에 고생들 많으십니까... 저는 고양시에서 버스기사로 근무하는 지체\xa0... 2021. 2. 1. — 국토교통부(장관 변창흠)는 파주시 시내버스 문 끼임 사고 등 각종 버스안전사고를 예방하기 위하여 금일(2월 1일) 17개 시,도, 버스업계,\xa0... 분류한 버스 차내 안전사고 데이터 중 텍스트 기반의 사고개요 데이터를 통계분석 패키지 R Project를 활용하여 텍스트 마이닝 분석을 수행하였다. 텍스트 마이닝을\xa0... 학위구분: 국내석사학위수여기관: 명지대학교 대학원 일반대학원 2021. 11. 22. — 시내버스 안에서 승객이 넘어져 다쳤다면 피해 승객의 고의성이 증명되지 않는 한 버스 회사에 배상 책임이 있다고 대법원이 판단했다. 2021. 5. 20. — 버스 내 안전사고는 69.4%, 버스 승하차 도중 사고는 17.6%로 각각 조사됐다. 버스 내 안전사고의 이유는 짧은 배차시간에 따른 과속 운전, 업무 과중\xa0... 2022. 8. 11. — 버스공제조합 자료에 따르면 지난해 차내 안전사고는 시내버스 전체사고의 약 62.3%를 차지하는 것으로 나타났다. 이에 전북본부는 대중교통 이용문화를\xa0... 2022. 10. 12. — 뒤를 쫓아가던 동료 버스 운전기사가 고의 사고를 내서 추가 피해를 막았습니다. 양동훈 기자입니다. [기자] 고속도로 갓길에서 중형 버스가 가드레일을\xa0... 2022. 4. 7. — 본 포스팅은 버스를 포함한 대중교통 이동수단과 관련해서 사고가 ... 내가 버스를 이용할 때 사고가 날 경우 버스공제조합에서 보상을 해줍니다. xxxx.xx 「시내버스 차내 안전사고 실태 조사」보고서 소비자안전본부 생활안전팀 목 차 Ⅰ. 조사개요 x x. 배경 및 목적x x. 조사 방법x Ⅱ. 일반현황 x x. 2018. 1. 29. — 그러나 요즘에는 버스 내 블랙박스가 설치되어 있기 때문에 사고 영상만 확보한다면 상황의 입증은 그렇게 어렵지 않다. 이런 경우 버스 탑승객\xa0... 사고사례 들여다보기. 통학버스 운행 중 사고 사례와 예방법. 어린이들이 통학버스에서 사고를 당하는 경우는 승차, 하차 시, 그리고 운행 중 사고유형으로 나눠볼 수\xa0... 2021. 5. 20. — 버스 내 안전사고가 발생하는 것은 과속운행, 짧은 배차시간, 과중한 업무 등이 있었고, 승객이 손잡이를 제대로 잡지 않고 있거나 버스 완전 정차\xa0... 2021. 5. 24. — 버스는 진로 변경 차량을 보고 급정지했으나 차로를 변경하는 승용차와 충돌하여 버스 내 승객이 부상을 입는 사고가 발생하고 말았다. 2019. 4. 22. — 차대차 충돌, 차대시설물 충돌, 탑승 중 차량 내 넘어짐, 출입문 끼임, 승객 하차 전 출발로 인한 추락, 승강장 사고, 도로횡단사고 등도 시내버스로\xa0... 2021. 5. 20. — 부산 시내버스 안전사고 대부분이 승하차 과정이거나 운행 중 내부에서 발생하는 것으로 확인되면서 탑승객들의 안전 인식개선이 필요하다는 지적이\xa0... 2022. 4. 27. — 내 사건을 의뢰하고, 변호사 제안서 받으세요. (주) 로앤굿. 사업자등록번호: 668-86-01551 | 대표이사: 민명기 | 주소: 서울특별시 강남구 테헤란로83\xa0... 2021. 3. 2. — 운전기사의 잘못이나 버스 관리 소홀로 승객이 피해를  ...

# %%
okt = Okt()
nouns = okt.nouns(result) # 명사만 추출

words = [n for n in nouns if len(n) > 1 and n != '버스'] # 단어의 길이가 1개인 것은 제외

c = Counter(words) # 위에서 얻은 words를 처리하여 단어별 빈도수 형태의 딕셔너리 데이터를 구함

# %%
from PIL import Image

# %%
im = Image.open('word_bus.jpg') # 이미지 파일 읽어오기 (워드로 만들 모양)
mask_arr = np.array(im)             # 픽셀 값 배열 형태 변환

# %%
wc = WordCloud(font_path='malgun', width=400, height=400, scale=2.0, max_font_size=250, mask=mask_arr)
# wc = WordCloud(font_path='malgun', width=400, height=400, scale=2.0, max_font_size=250)
gen = wc.generate_from_frequencies(c)
plt.figure(figsize=(20,12))
plt.imshow(gen)
