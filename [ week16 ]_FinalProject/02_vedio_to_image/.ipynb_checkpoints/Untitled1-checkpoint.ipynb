# %% [markdown]
# ## 영상 데이터에서 이미지 불러오기

# %%
#라이브러리 호출
import cv2
import os

print(cv2.__version__)
# Out:
# 4.6.0

# %%
filepath = './test.mp4'
video = cv2.VideoCapture(filepath)

# 비디오 파일이 아닐 경우(예외 경우) 처리
if not video.isOpened():
    print("Could not Open :", filepath)
    exit(0)

# %%
# 불러온 비디오 파일의 정보 출력
length = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = video.get(cv2.CAP_PROP_FPS)

print("length :", length)
print("width :", width)
print("height :", height)
print("fps :", fps)
# Out:
# length : 301
# width : 720
# height : 1280
# fps : 24.0

# %%
# 프레임을 저장할 디렉토리를 생성
try:
    if not os.path.exists(filepath[:-4]):
        os.makedirs(filepath[:-4])
except OSError:
    print ('Error: Creating directory. ' +  filepath[:-4])

# %%
count = 0

while(video.isOpened()):
    ret, image = video.read()
    if(int(video.get(1)) % fps == 0): #앞서 불러온 fps 값을 사용하여 1초마다 추출
        cv2.imwrite(filepath[:-4] + "/frame%d.jpg" % count, image)
        print('Saved frame number :', str(int(video.get(1))))
        count += 1
        
video.release()
# Out:
# Saved frame number : 24
# Saved frame number : 48
# Saved frame number : 72
# Saved frame number : 96
# Saved frame number : 120
# Saved frame number : 144
# Saved frame number : 168
# Saved frame number : 192
# Saved frame number : 216
# Saved frame number : 240
# Saved frame number : 264
# Saved frame number : 288
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14108\3958750689.py in <module>
#       2
#       3 while(video.isOpened()):
# ----> 4     ret, image = video.read()
#       5     if(int(video.get(1)) % fps == 0): #앞서 불러온 fps 값을 사용하여 1초마다 추출
#       6         cv2.imwrite(filepath[:-4] + "/frame%d.jpg" % count, image)
#
# KeyboardInterrupt:

# %%
# 12초 영상, 프레임을 저장

# %%
cap = cv2.VideoCapture('/test.mp4')
# cap = cv2.VideoCapture(f"{VideoPath}")

# %%
def readFrame(cap, frame):
    cap.set(cv2.CAP_PROP_POS_FRAMES, frame)
    ok, image = cap.read()

    if not ok:
        raise "프레임 없음"
    return image

# %%
# -*- coding: utf-8 -*-
__author__ = 'Seran'
 
import cv2
 
# 영상의 의미지를 연속적으로 캡쳐할 수 있게 하는 class
vidcap = cv2.VideoCapture('test.mp4')
 
count = 0
 
while(vidcap.isOpened()):
    # read()는 grab()와 retrieve() 두 함수를 한 함수로 불러옴
    # 두 함수를 동시에 불러오는 이유는 프레임이 존재하지 않을 때
    # grab() 함수를 이용하여 return false 혹은 NULL 값을 넘겨 주기 때문
    ret, image = vidcap.read()
 
    # 캡쳐된 이미지를 저장하는 함수 
    cv2.imwrite("/images/frame%d.jpg" % count, image)
 
    print('Saved frame%d.jpg' % count)
    count += 1
 
vidcap.release()
# Out:
# Saved frame0.jpg
# Saved frame1.jpg
# Saved frame2.jpg
# Saved frame3.jpg
# Saved frame4.jpg
# Saved frame5.jpg
# Saved frame6.jpg
# Saved frame7.jpg
# Saved frame8.jpg
# Saved frame9.jpg
# Saved frame10.jpg
# Saved frame11.jpg
# Saved frame12.jpg
# Saved frame13.jpg
# Saved frame14.jpg
# Saved frame15.jpg
# Saved frame16.jpg
# Saved frame17.jpg
# Saved frame18.jpg
# Saved frame19.jpg
# Saved frame20.jpg
# Saved frame21.jpg
# Saved frame22.jpg
# Saved frame23.jpg
# Saved frame24.jpg
# Saved frame25.jpg
# Saved frame26.jpg
# Saved frame27.jpg
# Saved frame28.jpg
# Saved frame29.jpg
# Saved frame30.jpg
# Saved frame31.jpg
# Saved frame32.jpg
# Saved frame33.jpg
# Saved frame34.jpg
# Saved frame35.jpg
# Saved frame36.jpg
# Saved frame37.jpg
# Saved frame181.jpg
# Saved frame182.jpg
# Saved frame183.jpg
# Saved frame184.jpg
# Saved frame185.jpg
# Saved frame186.jpg
# Saved frame187.jpg
# Saved frame188.jpg
# Saved frame189.jpg
# Saved frame190.jpg
# Saved frame191.jpg
# Saved frame192.jpg
# Saved frame193.jpg
# Saved frame194.jpg
# Saved frame195.jpg
# Saved frame196.jpg
# Saved frame197.jpg
# Saved frame198.jpg
# Saved frame199.jpg
# Saved frame200.jpg
# Saved frame201.jpg
# Saved frame202.jpg
# Saved frame203.jpg
# Saved frame204.jpg
# Saved frame205.jpg
# Saved frame206.jpg
# Saved frame207.jpg
# Saved frame208.jpg
# Saved frame209.jpg
# Saved frame210.jpg
# Saved frame211.jpg
# Saved frame212.jpg
# Saved frame213.jpg
# Saved frame214.jpg
# Saved frame215.jpg
# Saved frame216.jpg
# Saved frame217.jpg
# Saved frame218.jpg
# Saved frame219.jpg
# Saved frame220.jpg
# Saved frame221.jpg
# Saved frame222.jpg
# Saved frame223.jpg
# Saved frame224.jpg
# Saved frame225.jpg
# Saved frame226.jpg
# Saved frame227.jpg
# Saved frame228.jpg
# Saved frame229.jpg
# Saved frame230.jpg
# Saved frame231.jpg
# Saved frame232.jpg
# Saved frame233.jpg
# Saved frame234.jpg
# Saved frame235.jpg
# Saved frame236.jpg
# Saved frame237.jpg
# Saved frame238.jpg
# Saved frame239.jpg
# Saved frame240.jpg
# Saved frame241.jpg
# Saved frame242.jpg
# Saved frame243.jpg
# Saved frame244.jpg
# Saved frame245.jpg
# Saved frame246.jpg
# Saved frame247.jpg
# Saved frame248.jpg
# Saved frame249.jpg
# Saved frame250.jpg
# Saved frame251.jpg
# Saved frame252.jpg
# Saved frame253.jpg
# Saved frame254.jpg
# Saved frame255.jpg
# Saved frame256.jpg
# Saved frame257.jpg
# Saved frame258.jpg
# Saved frame259.jpg
# Saved frame260.jpg
# Saved frame261.jpg
# Saved frame262.jpg
# Saved frame263.jpg
# Saved frame264.jpg
# Saved frame265.jpg
# Saved frame266.jpg
# Saved frame267.jpg
# Saved frame268.jpg
# Saved frame269.jpg
# Saved frame270.jpg
# Saved frame271.jpg
# Saved frame272.jpg
# Saved frame273.jpg
# Saved frame274.jpg
# Saved frame275.jpg
# Saved frame276.jpg
# Saved frame277.jpg
# Saved frame278.jpg
# Saved frame279.jpg
# Saved frame280.jpg
# Saved frame281.jpg
# Saved frame282.jpg
# Saved frame283.jpg
# Saved frame284.jpg
# Saved frame285.jpg
# Saved frame286.jpg
# Saved frame287.jpg
# Saved frame288.jpg
# Saved frame289.jpg
# Saved frame290.jpg
# Saved frame291.jpg
# Saved frame292.jpg
# Saved frame293.jpg
# Saved frame294.jpg
# Saved frame295.jpg
# Saved frame296.jpg
# Saved frame297.jpg
# Saved frame298.jpg
# Saved frame299.jpg
# Saved frame300.jpg
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12884\10795597.py in <module>
#      16
#      17     # 캡쳐된 이미지를 저장하는 함수
# ---> 18     cv2.imwrite("/images/frame%d.jpg" % count, image)
#      19
#      20     print('Saved frame%d.jpg' % count)
#
# error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:801: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'

# %%
while(vidcap.isOpened()):
    ret, image = vidcap.read()
 
    if(int(vidcap.get(1)) % 20 == 0):
        print('Saved frame number : ' + str(int(vidcap.get(1))))
        cv2.imwrite("../images/frame%d.jpg" % count, image)
        print('Saved frame%d.jpg' % count)
        count += 1

# %%
# 이미지의 객체 인식

# %%
import cv2
import numpy as np
