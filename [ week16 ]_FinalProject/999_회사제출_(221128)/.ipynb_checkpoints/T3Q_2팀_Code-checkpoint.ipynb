# %% [markdown]
# # 로컬 개발 코드
# - 로컬에서 주피터 노트북(Jupyter Notebook), 주피터 랩(JupyterLab) 또는 파이썬(Python)을 이용한다.
# - 사이킷 런(scikit-learn), 텐서플로우(tensorflow), 파이토치(pytorch)를 사용하여 딥러닝 프로그램을 개발한다.
# - 파일명: 0_local_text_generation.ipynb
#
# ### 로컬 개발 워크플로우(workflow)
# - 로컬 개발 워크플로우를 다음의 4단계로 분리한다.
#
# 1. **데이터셋 준비(Data Setup)**
# - 로컬 저장소에서 전처리 및 학습에 필요한 학습 데이터셋을 준비한다.
#
# 2. **데이터 전처리(Data Preprocessing)**
# - 데이터셋의 분석 및 정규화(Normalization)등의 전처리를 수행한다.
# - 데이터를 모델 학습에 사용할 수 있도록 가공한다.
# - 추론과정에서 필요한 경우, 데이터 전처리에 사용된 객체를 meta_data 폴더 아래에 저장한다.
#
# 3. **학습 모델 훈련(Train Model)**
# - 데이터를 훈련에 사용할 수 있도록 가공한 뒤에 학습 모델을 구성한다.
# - 학습 모델을 준비된 데이터셋으로 훈련시킨다.
# - 정확도(Accuracy)나 손실(Loss)등 학습 모델의 성능을 검증한다.
# - 학습 모델의 성능 검증 후, 학습 모델을 배포한다.
# - 배포할 학습 모델을 meta_data 폴더 아래에 저장한다.
#
# 4. **추론(Inference)**
# - 저장된 전처리 객체나 학습 모델 객체를 준비한다.
# - 추론에 필요한 테스트 데이터셋을 준비한다.
# - 배포된 학습 모델을 통해 테스트 데이터에 대한 추론을 진행한다.

# %% [markdown]
# # 승하차 분류 (Classification)
# - 지금부터 skeleton points를 이용하여 승하차 분류 (classification)을 진행해보고자 한다.

# %% [markdown]
# ## 승하차
#
# ### 사용할 데이터
#
# - aihub에서 제공하는 Open Dataset
# - 해당 데이터셋은 원천 데이터인 이미지 데이터와 annotations 정보를 가진 json 파일들로 이루어져 있다.
#
# ### 사용할 4개의 annotations 정보
# - keypoints
# - get_on
# - get_off
# - action

# %% [markdown]
# ## **1. 데이터셋 준비(Data Setup)**

# %%
# 모듈 로딩
import json
import pandas as pd
import os
import matplotlib.pyplot as plt
from tqdm import tqdm
import numpy as np
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

from keras.models import Sequential
from tensorflow.keras.optimizers import Adam,SGD,RMSprop,Adagrad
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import to_categorical

from keras.layers import Dropout, Flatten, LSTM, Bidirectional, Dense, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D, Conv3D, MaxPool2D

# %%
C3_downtown = 'C:/Users/USER/Desktop/승하차 데이터/[라벨]General_train_C_3/downtown/'
C3_supermarket = 'C:/Users/USER/Desktop/승하차 데이터/[라벨]General_train_C_3/supermarket/'
C3_village = 'C:/Users/USER/Desktop/승하차 데이터/[라벨]General_train_C_3/village/'
A1_apt = 'C:/Users/USER/Desktop/승하차 데이터/[라벨]General_train_A_1/apt/'
A1_etc = 'C:/Users/USER/Desktop/승하차 데이터/[라벨]General_train_A_1/etc/'
A1_supermarket = 'C:/Users/USER/Desktop/승하차 데이터/[라벨]General_train_A_1/supermarket/'
A2_apt = 'C:/Users/USER/Desktop/승하차 데이터/[라벨]General_train_A_2/apt/'
A2_hospital = 'C:/Users/USER/Desktop/승하차 데이터/[라벨]General_train_A_2/hospital/'
A2_village = 'C:/Users/USER/Desktop/승하차 데이터/[라벨]General_train_A_2/village/'
A3_downtown = 'C:/Users/USER/Desktop/승하차 데이터/[라벨]General_train_A_3/downtown/'
A3_mid_high = 'C:/Users/USER/Desktop/승하차 데이터/[라벨]General_train_A_3/mid_high/'
A3_subway = 'C:/Users/USER/Desktop/승하차 데이터/[라벨]General_train_A_3/subway/'
A3_university = 'C:/Users/USER/Desktop/승하차 데이터/[라벨]General_train_A_3/university/'
B1_district = 'C:/Users/USER/Desktop/승하차 데이터/[라벨]General_train_B_1/district/'
B1_etc = 'C:/Users/USER/Desktop/승하차 데이터/[라벨]General_train_B_1/etc/'
B1_hospital = 'C:/Users/USER/Desktop/승하차 데이터/[라벨]General_train_B_1/hospital/'
B2_downtown = 'C:/Users/USER/Desktop/승하차 데이터/[라벨]General_train_B_2/downtown/'
B2_mid_high = 'C:/Users/USER/Desktop/승하차 데이터/[라벨]General_train_B_2/mid_high/'
B2_university = 'C:/Users/USER/Desktop/승하차 데이터/[라벨]General_train_B_2/university/'
B3_ele = 'C:/Users/USER/Desktop/승하차 데이터/[라벨]General_train_B_3/ele/'
B3_supermarket = 'C:/Users/USER/Desktop/승하차 데이터/[라벨]General_train_B_3/supermarket/'
B3_village = 'C:/Users/USER/Desktop/승하차 데이터/[라벨]General_train_B_3/village/'
C1_apt = 'C:/Users/USER/Desktop/승하차 데이터/[라벨]General_train_C_1/apt/'
C2_ele = 'C:/Users/USER/Desktop/승하차 데이터/[라벨]General_train_C_2/ele/'
C2_etc = 'C:/Users/USER/Desktop/승하차 데이터/[라벨]General_train_C_2/etc/'
C2_hospital = 'C:/Users/USER/Desktop/승하차 데이터/[라벨]General_train_C_2/hospital/'
C2_mid_high = 'C:/Users/USER/Desktop/승하차 데이터/[라벨]General_train_C_2/mid_high/'
C2_university = 'C:/Users/USER/Desktop/승하차 데이터/[라벨]General_train_C_2/university/'

# %%
def make_df(path):
    bbox = []
    keypoints = []
    action = []
    get_on = []
    get_off = []
    for i in tqdm(os.listdir(path)):
        os.listdir(path+i)
        file_list = os.listdir(path+i)
       
        for a in file_list:
            with open ((path+i+'/'+a),"r") as j:
                contents = json.loads(j.read())
                if len(contents['annotations']) != 0:
                    for idx in range(len(contents['annotations'])):
                            bbox.append(contents['annotations'][idx]['bbox'])
                            keypoints.append(contents['annotations'][idx]['keypoints'])
                            action.append(contents['annotations'][idx]['action'])
                            get_on.append(contents['annotations'][idx]['get_on'])
                            get_off.append(contents['annotations'][idx]['get_off'])
    df = pd.DataFrame({'bbox':bbox,
                       'keypoints':keypoints,
                       'action':action,
                       'get_on':get_on,
                       'get_off':get_off})
    get = []
    action_num = []
    for i in tqdm(range(len(df['get_on']))):
        if (list(df['get_on'])[i] == False) and (list(df['get_off'])[i] == False):
            get.append(2)
        elif (list(df['get_on'])[i] == True) and (list(df['get_off'])[i] == False):
            get.append(1)
        else:
            get.append(0)
    df['get'] = get
    
    for i in tqdm(range(len(df['action']))):
        if list(df['action'])[i] == 'stand':
            action_num.append(0) 
        elif list(df['action'])[i] == 'walk':
            action_num.append(1)
        elif list(df['action'])[i] == 'run':
            action_num.append(2)
        elif list(df['action'])[i] == 'sit down':
            action_num.append(3)
        elif list(df['action'])[i] == 'lay down':
            action_num.append(4)
        elif list(df['action'])[i] == 'grab handle':
            action_num.append(5)
        elif list(df['action'])[i] == 'kick':
            action_num.append(6)
        else:
            action_num.append(7)
    df['action_num'] = action_num
    
    return df

# %%
C3_downtown_df = make_df(C3_downtown)
C3_supermarket_df = make_df(C3_supermarket)
C3_village_df = make_df(C3_village)
A1_apt_df = make_df(A1_apt)
A1_etc_df = make_df(A1_etc)
A1_supermarket_df = make_df(A1_supermarket)
A2_apt_df = make_df(A2_apt)
A2_hospital_df = make_df(A2_hospital)
A2_village_df = make_df(A2_village)
A3_downtown_df = make_df(A3_downtown)
A3_mid_high_df = make_df(A3_mid_high)
A3_subway_df = make_df(A3_subway)
A3_university_df = make_df(A3_university)
B1_district_df = make_df(B1_district)
B1_etc_df = make_df(B1_etc)
B1_hospital_df = make_df(B1_hospital)
B2_downtown_df = make_df(B2_downtown)
B2_mid_high_df = make_df(B2_mid_high)
B2_university_df = make_df(B2_university)
B3_ele_df = make_df(B3_ele)
B3_supermarket_df = make_df(B3_supermarket)
B3_village_df = make_df(B3_village)
C1_apt_df = make_df(C1_apt)
C2_ele_df = make_df(C2_ele)
C2_etc_df = make_df(C2_etc)
C2_hospital_df = make_df(C2_hospital)
C2_mid_high_df = make_df(C2_mid_high)
C2_university_df = make_df(C2_university)

# %%
bus_df = pd.concat([A1_apt_df,A1_etc_df,A1_supermarket_df,A2_apt_df,
                   A2_hospital_df,A2_village_df,A3_downtown_df,A3_mid_high_df,A3_subway_df,A3_university_df,B1_district_df,
                   B1_etc_df,B1_hospital_df,B2_downtown_df,B2_mid_high_df,B2_university_df,B3_ele_df,B3_supermarket_df,
                   B3_village_df,C1_apt_df,C2_ele_df,C2_etc_df,C2_hospital_df,C2_mid_high_df,C2_university_df,C3_downtown_df,C3_supermarket_df,C3_village_df])

# %%
bus_df.to_csv('./getonoff(train).csv', index=False, encoding='cp949')

# %%
df = pd.read_csv('./bus_getonoff.csv')

# %%
df
# Out:
#                            bbox  \
# 0        [974, 266, 1471, 1077]
# 1       [1017, 224, 1452, 1060]
# 2       [1007, 224, 1445, 1049]
# 3       [1007, 222, 1428, 1049]
# 4        [995, 220, 1421, 1044]
# ...                         ...
# 939213   [744, 404, 1349, 1079]
# 939214    [771, 193, 1523, 923]
# 939215   [669, 316, 1224, 1079]
# 939216    [794, 236, 1523, 867]
# 939217   [716, 287, 1263, 1079]
#
#                                                 keypoints       action  \
# 0       [1074, 1020, 2, 1111, 923, 2, 1151, 752, 2, 12...        stand
# 1       [1094, 918, 2, 1131, 802, 2, 1185, 643, 2, 131...        stand
# 2       [1085, 909, 2, 1118, 787, 2, 1174, 634, 2, 129...        stand
# 3       [1082, 908, 2, 1113, 786, 2, 1155, 627, 2, 127...        stand
# 4       [1071, 904, 2, 1102, 782, 2, 1144, 623, 2, 127...        stand
# ...                                                   ...          ...
# 939213  [1105, 1022, 0, 1105, 913, 0, 1105, 807, 0, 15...        stand
# 939214  [1030, 889, 1, 1006, 799, 1, 1010, 714, 1, 903...  grab handle
# 939215  [1105, 1022, 0, 1105, 913, 0, 1105, 807, 0, 15...        stand
# 939216  [1016, 839, 1, 1013, 766, 1, 1031, 704, 1, 926...  grab handle
# 939217  [1145, 1019, 0, 1145, 906, 0, 1084, 1017, 2, 9...         walk
#
#         get_on  get_off  get_num  action_num
# 0         True    False        1           0
# 1         True    False        1           0
# 2         True    False        1           0
# 3         True    False        1           0
# 4         True    False        1           0
# ...        ...      ...      ...         ...
# 939213   False     True        0           0
# 939214   False     True        0           5
# 939215   False     True        0           0
# 939216   False     True        0           5
# 939217   False     True        0           1
#
# [939218 rows x 7 columns]

# %%
df = df.iloc[:893905,:]

# %%
df['get_num'].value_counts()
# Out:
# 2    552659
# 0    211230
# 1    130016
# Name: get_num, dtype: int64

# %%
df
# Out:
#                            bbox  \
# 0        [974, 266, 1471, 1077]
# 1       [1017, 224, 1452, 1060]
# 2       [1007, 224, 1445, 1049]
# 3       [1007, 222, 1428, 1049]
# 4        [995, 220, 1421, 1044]
# ...                         ...
# 803900     [706, 338, 905, 897]
# 803901   [1118, 242, 1282, 622]
# 803902     [587, 235, 731, 603]
# 803903     [688, 217, 870, 672]
# 803904     [703, 338, 905, 911]
#
#                                                 keypoints    action  get_on  \
# 0       [1074, 1020, 2, 1111, 923, 2, 1151, 752, 2, 12...     stand    True
# 1       [1094, 918, 2, 1131, 802, 2, 1185, 643, 2, 131...     stand    True
# 2       [1085, 909, 2, 1118, 787, 2, 1174, 634, 2, 129...     stand    True
# 3       [1082, 908, 2, 1113, 786, 2, 1155, 627, 2, 127...     stand    True
# 4       [1071, 904, 2, 1102, 782, 2, 1144, 623, 2, 127...     stand    True
# ...                                                   ...       ...     ...
# 803900  [801, 834, 1, 797, 746, 1, 811, 649, 2, 849, 6...     stand   False
# 803901  [1135, 596, 1, 1148, 472, 1, 1160, 432, 1, 123...  sit down   False
# 803902  [626, 574, 1, 605, 456, 1, 635, 411, 2, 690, 4...  sit down   False
# 803903  [719, 604, 2, 714, 479, 2, 756, 429, 1, 844, 4...  sit down   False
# 803904  [796, 822, 1, 794, 745, 1, 796, 652, 2, 835, 6...     stand   False
#
#         get_off  get  action_num
# 0         False    1           0
# 1         False    1           0
# 2         False    1           0
# 3         False    1           0
# 4         False    1           0
# ...         ...  ...         ...
# 803900     True    0           0
# 803901    False    2           3
# 803902    False    2           3
# 803903    False    2           3
# 803904     True    0           0
#
# [803905 rows x 7 columns]

# %% [markdown]
# ## 2. 데이터 전처리 (Data Preprocessing)

# %% [markdown]
# ### 데이터 준비 (Preparing Data)
#
# 앞서 확인하고 분석한 numpy array들을 훈련에 사용할 수 있는 형태로 바꾸고자 한다.
#
# - 데이터 전처리
#   - skeleton 좌표인 16개의 keypoints가 각각의 list에 들어가 있다. '[','[' 문자를 제거하고 하나의 list로 만들어준다. (strip)
#   - train, test data 분리 위해 리스트를 2차원 배열로 만든다.
# - 훈련 (train) & 평가 (test) 데이터셋 생성
#   - 전체 데이터 중 일부는 훈련 (train)에 사용하고, 나머지 일부는 훈련된 모델의 성능을 평가 (test)하기 위해 사용하고자 한다. (`train_test_split`)
# - stratified k-fold 교차검증
#   - label 데이터 불균형을 해결하기 위해 교차검증을 진행한다. (stratified k-fold)
#   - 교차검증을 진행하기 위해 훈련 데이터 x_train을 DataFrame으로 만들어준다.

# %% [markdown]
# #### 데이터 전처리

# %%
# keypoints list 생성
keypoints_list = []
for i in tqdm(range(len(df['keypoints']))):
    keypoints_list.append(np.array(list(map(int,df.keypoints[i].strip('[').strip(']').split(',')))))
    
# train, test 분리 위해 list를 2차열 배열로 변경해준다.
keypoints2arr = np.array(keypoints_list)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 893905/893905 [00:18<00:00, 48792.77it/s]

# %%
keypoints2arr.shape
# Out:
# (893905, 48)

# %% [markdown]
# ##### 훈련 & 평가 데이터셋 생성
#
# 전체 데이터셋 중 **8:2**의 비율로 훈련:평가 데이터셋을 생성한다.

# %%
# train, test 데이터셋 생성
x_train,x_test,y_train,y_test=train_test_split(keypoints2arr,df['get_num'],
                                               test_size=0.2,
                                               random_state=42,
                                               shuffle=True)

# %% [markdown]
# #### stratified k-fold 교차검증

# %%
# 교차 검증 위해 DataFrame 변경
x_df = pd.DataFrame(x_train)

str_kf = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 50)

# 교차검증 accuracy 담을 list 생성 
acc_score = []

# %% [markdown]
# ## **3. 학습 모델 훈련 (Train Model)**
#
# 승하차 분류를 위해 아주 간단한 CNN 모델을 Keras를 이용하여 구축하고자 한다.

# %%
# CNN 모델 구축
def model_CNN():

    model=Sequential()
    model.add(Conv2D(128, kernel_size=3, padding='same', input_shape=(16, 1, 3))) # 3차원
    model.add(MaxPool2D(pool_size=2, padding='same'))

    model.add(Flatten()) # 1차원으로 데이터 형태 변환 Layer 
    model.add(Dense(128, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(3, activation='softmax')) # get_on, get_of, nothing 출력

    return model

# %%
# EarlyStopping(val_loss 10회 이상 개선 없을시 멈춘다.)
patience = 10
stopCB = EarlyStopping(monitor='val_loss', patience=patience)

# ModelCheckpoint는 모델이 학습하면서 정의한 조건을 만족했을 때 Model의 weight 값을 중간 저장.
MODEL_DIR = './model/'               # 모델을 저장하는 폴더
if not os.path.exists(MODEL_DIR):    # 만일 위의 폴더가 존재하지 않으면
    os.mkdir(MODEL_DIR)              # 이 이름의 폴더를 만들어준다.
    
modelpath='./model/{epoch:02d}-{val_loss:.4f}.hdf5' # epoch-val_loss 이름으로 저장

checkpointer = ModelCheckpoint(filepath=modelpath,  # file명 지정
                               monitor ='val_loss', # val_loss 값이 개선 되었을때 호출
                               verbose=1,           # 로그 출력 
                               save_best_only=True) # val_loss best 값 저장

# %% [markdown]
# ### 모델 컴파일 및 학습 (Compile and Train Model)
#
# - 모델 컴파일 (Compile Model)
#   - Keras의 compile 함수를 통해 모델의 optimizer, loss, 그리고 metrics를 선택할 수 있다.
#   - Loss: categoriacal_crossentropy
#     - 우리는 레이블로 one-hot-encoding을 사용했으므로 loss로 'categorical_crossentropy'를 사용한다.
# - 모델 학습 (Train Model)
#   - 앞서 구축한 모델을 준비해준 입력 데이터와 레이블 데이터로 학습시킨다.

# %%
# 모델 학습(Train Model)
for train_index, test_index in str_kf.split(x_df, y_train): 
    X_train, X_val = x_df.iloc[train_index,:], x_df.iloc[test_index,:]  
    y_train2, y_val = y_train.iloc[train_index], y_train.iloc[test_index]
    
    X_train = np.array(X_train).reshape(-1,16,1,3)
    y_train2 = to_categorical(y_train2, num_classes=3)
    X_val = np.array(X_val).reshape(-1,16,1,3)
    y_val = to_categorical(y_val, num_classes=3)    
    
    with tf.device("/device:GPU:0"):
        
        # 모델 컴파일(Compile Model)
        model = model_CNN()
        model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
        hist = model.fit(X_train,y_train2,epochs=100 ,batch_size=128,validation_data=(X_val,y_val),callbacks=[stopCB,checkpointer])

        # epoch 마다 train, validation의 accuracy, loss 시각화
        epochs = hist.epoch
        fig , ax = plt.subplots(1,2)
        train_acc = hist.history['accuracy']
        train_loss = hist.history['loss']
        val_acc = hist.history['val_accuracy']
        val_loss = hist.history['val_loss']
        fig.set_size_inches(20,10)

        ax[0].plot(epochs , train_acc , 'go-' , label = 'Training Accuracy')
        ax[0].plot(epochs , val_acc , 'ro-' , label = 'Val Accuracy')
        ax[0].set_title('Training & Val Accuracy')
        ax[0].legend()
        ax[0].set_xlabel("Epochs")
        ax[0].set_ylabel("Accuracy")

        ax[1].plot(epochs , train_loss , 'g-o' , label = 'Training Loss')
        ax[1].plot(epochs , val_loss , 'r-o' , label = 'Val Loss')
        ax[1].set_title('Training & Val Loss')
        ax[1].legend()
        ax[1].set_xlabel("Epochs")
        ax[1].set_ylabel("Loss")
        plt.show()
        
        # 모델 평가
        y_pred2 = model.predict(x_test.reshape(-1,16,1,3))
        y_pred2 = np.argmax(y_pred2, axis=1)
        y_test2 = np.argmax(to_categorical(y_test, num_classes=3), axis=1)

        print(confusion_matrix(y_test2,y_pred2))
        print(accuracy_score(y_test2,y_pred2))
        acc_score.append(accuracy_score(y_test2,y_pred2))
        print(classification_report(y_test2,y_pred2))
# Out:
# Epoch 1/100
# 4465/4470 [============================>.] - ETA: 0s - loss: 0.6762 - accuracy: 0.7687
# Epoch 1: val_loss did not improve from 0.43611
# 4470/4470 [==============================] - 17s 4ms/step - loss: 0.6761 - accuracy: 0.7687 - val_loss: 0.5007 - val_accuracy: 0.8089
# Epoch 2/100
# 4465/4470 [============================>.] - ETA: 0s - loss: 0.4920 - accuracy: 0.8196
# Epoch 2: val_loss did not improve from 0.43611
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.4920 - accuracy: 0.8196 - val_loss: 0.4556 - val_accuracy: 0.8298
# Epoch 3/100
# 4460/4470 [============================>.] - ETA: 0s - loss: 0.4571 - accuracy: 0.8324
# Epoch 3: val_loss improved from 0.43611 to 0.43386, saving model to ./model\03-0.4339.hdf5
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.4571 - accuracy: 0.8324 - val_loss: 0.4339 - val_accuracy: 0.8420
# Epoch 4/100
# 4452/4470 [============================>.] - ETA: 0s - loss: 0.4371 - accuracy: 0.8401
# Epoch 4: val_loss improved from 0.43386 to 0.42313, saving model to ./model\04-0.4231.hdf5
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.4370 - accuracy: 0.8401 - val_loss: 0.4231 - val_accuracy: 0.8454
# Epoch 5/100
# 4470/4470 [==============================] - ETA: 0s - loss: 0.4259 - accuracy: 0.8446
# Epoch 5: val_loss improved from 0.42313 to 0.39875, saving model to ./model\05-0.3988.hdf5
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.4259 - accuracy: 0.8446 - val_loss: 0.3988 - val_accuracy: 0.8521
# Epoch 6/100
# 4463/4470 [============================>.] - ETA: 0s - loss: 0.4178 - accuracy: 0.8477
# Epoch 6: val_loss did not improve from 0.39875
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.4178 - accuracy: 0.8478 - val_loss: 0.4037 - val_accuracy: 0.8534
# Epoch 7/100
# 4466/4470 [============================>.] - ETA: 0s - loss: 0.4107 - accuracy: 0.8505
# Epoch 7: val_loss improved from 0.39875 to 0.39864, saving model to ./model\07-0.3986.hdf5
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.4107 - accuracy: 0.8505 - val_loss: 0.3986 - val_accuracy: 0.8546
# Epoch 8/100
# 4456/4470 [============================>.] - ETA: 0s - loss: 0.4053 - accuracy: 0.8525
# Epoch 8: val_loss improved from 0.39864 to 0.39339, saving model to ./model\08-0.3934.hdf5
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.4053 - accuracy: 0.8525 - val_loss: 0.3934 - val_accuracy: 0.8569
# Epoch 9/100
# 4468/4470 [============================>.] - ETA: 0s - loss: 0.4032 - accuracy: 0.8533
# Epoch 9: val_loss improved from 0.39339 to 0.37917, saving model to ./model\09-0.3792.hdf5
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.4031 - accuracy: 0.8534 - val_loss: 0.3792 - val_accuracy: 0.8600
# Epoch 10/100
# 4463/4470 [============================>.] - ETA: 0s - loss: 0.3993 - accuracy: 0.8549
# Epoch 10: val_loss did not improve from 0.37917
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3992 - accuracy: 0.8549 - val_loss: 0.3944 - val_accuracy: 0.8582
# Epoch 11/100
# 4461/4470 [============================>.] - ETA: 0s - loss: 0.3972 - accuracy: 0.8559
# Epoch 11: val_loss did not improve from 0.37917
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3973 - accuracy: 0.8559 - val_loss: 0.3836 - val_accuracy: 0.8610
# Epoch 12/100
# 4469/4470 [============================>.] - ETA: 0s - loss: 0.3930 - accuracy: 0.8576
# Epoch 12: val_loss did not improve from 0.37917
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3930 - accuracy: 0.8576 - val_loss: 0.3965 - val_accuracy: 0.8554
# Epoch 13/100
# 4465/4470 [============================>.] - ETA: 0s - loss: 0.3912 - accuracy: 0.8581
# Epoch 13: val_loss did not improve from 0.37917
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3913 - accuracy: 0.8581 - val_loss: 0.3830 - val_accuracy: 0.8607
# Epoch 14/100
# 4468/4470 [============================>.] - ETA: 0s - loss: 0.3908 - accuracy: 0.8582
# Epoch 14: val_loss did not improve from 0.37917
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3908 - accuracy: 0.8582 - val_loss: 0.3807 - val_accuracy: 0.8625
# Epoch 15/100
# 4463/4470 [============================>.] - ETA: 0s - loss: 0.3911 - accuracy: 0.8581
# Epoch 15: val_loss improved from 0.37917 to 0.37739, saving model to ./model\15-0.3774.hdf5
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3910 - accuracy: 0.8581 - val_loss: 0.3774 - val_accuracy: 0.8655
# Epoch 16/100
# 4470/4470 [==============================] - ETA: 0s - loss: 0.3881 - accuracy: 0.8599
# Epoch 16: val_loss did not improve from 0.37739
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3881 - accuracy: 0.8599 - val_loss: 0.3789 - val_accuracy: 0.8602
# Epoch 17/100
# 4465/4470 [============================>.] - ETA: 0s - loss: 0.3849 - accuracy: 0.8608
# Epoch 17: val_loss did not improve from 0.37739
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3849 - accuracy: 0.8608 - val_loss: 0.3920 - val_accuracy: 0.8578
# Epoch 18/100
# 4463/4470 [============================>.] - ETA: 0s - loss: 0.3852 - accuracy: 0.8600
# Epoch 18: val_loss improved from 0.37739 to 0.36594, saving model to ./model\18-0.3659.hdf5
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3852 - accuracy: 0.8600 - val_loss: 0.3659 - val_accuracy: 0.8678
# Epoch 19/100
# 4467/4470 [============================>.] - ETA: 0s - loss: 0.3836 - accuracy: 0.8617
# Epoch 19: val_loss did not improve from 0.36594
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3836 - accuracy: 0.8617 - val_loss: 0.3747 - val_accuracy: 0.8657
# Epoch 20/100
# 4463/4470 [============================>.] - ETA: 0s - loss: 0.3831 - accuracy: 0.8616
# Epoch 20: val_loss did not improve from 0.36594
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3832 - accuracy: 0.8616 - val_loss: 0.3698 - val_accuracy: 0.8656
# Epoch 21/100
# 4468/4470 [============================>.] - ETA: 0s - loss: 0.3818 - accuracy: 0.8623
# Epoch 21: val_loss did not improve from 0.36594
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3818 - accuracy: 0.8623 - val_loss: 0.3766 - val_accuracy: 0.8657
# Epoch 22/100
# 4456/4470 [============================>.] - ETA: 0s - loss: 0.3816 - accuracy: 0.8622
# Epoch 22: val_loss did not improve from 0.36594
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3816 - accuracy: 0.8622 - val_loss: 0.3707 - val_accuracy: 0.8656
# Epoch 23/100
# 4464/4470 [============================>.] - ETA: 0s - loss: 0.3791 - accuracy: 0.8632
# Epoch 23: val_loss did not improve from 0.36594
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3790 - accuracy: 0.8632 - val_loss: 0.3715 - val_accuracy: 0.8659
# Epoch 24/100
# 4463/4470 [============================>.] - ETA: 0s - loss: 0.3780 - accuracy: 0.8633
# Epoch 24: val_loss improved from 0.36594 to 0.36574, saving model to ./model\24-0.3657.hdf5
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3780 - accuracy: 0.8633 - val_loss: 0.3657 - val_accuracy: 0.8708
# Epoch 25/100
# 4464/4470 [============================>.] - ETA: 0s - loss: 0.3789 - accuracy: 0.8633
# Epoch 25: val_loss improved from 0.36574 to 0.36179, saving model to ./model\25-0.3618.hdf5
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3789 - accuracy: 0.8633 - val_loss: 0.3618 - val_accuracy: 0.8693
# Epoch 26/100
# 4468/4470 [============================>.] - ETA: 0s - loss: 0.3783 - accuracy: 0.8632
# Epoch 26: val_loss did not improve from 0.36179
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3783 - accuracy: 0.8632 - val_loss: 0.3775 - val_accuracy: 0.8638
# Epoch 27/100
# 4462/4470 [============================>.] - ETA: 0s - loss: 0.3784 - accuracy: 0.8635
# Epoch 27: val_loss did not improve from 0.36179
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3785 - accuracy: 0.8634 - val_loss: 0.3795 - val_accuracy: 0.8664
# Epoch 28/100
# 4464/4470 [============================>.] - ETA: 0s - loss: 0.3774 - accuracy: 0.8641
# Epoch 28: val_loss did not improve from 0.36179
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3774 - accuracy: 0.8641 - val_loss: 0.3646 - val_accuracy: 0.8681
# Epoch 29/100
# 4460/4470 [============================>.] - ETA: 0s - loss: 0.3761 - accuracy: 0.8639
# Epoch 29: val_loss did not improve from 0.36179
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3761 - accuracy: 0.8638 - val_loss: 0.3711 - val_accuracy: 0.8700
# Epoch 30/100
# 4462/4470 [============================>.] - ETA: 0s - loss: 0.3757 - accuracy: 0.8649
# Epoch 30: val_loss did not improve from 0.36179
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3758 - accuracy: 0.8648 - val_loss: 0.3816 - val_accuracy: 0.8629
# Epoch 31/100
# 4470/4470 [==============================] - ETA: 0s - loss: 0.3758 - accuracy: 0.8645
# Epoch 31: val_loss improved from 0.36179 to 0.35824, saving model to ./model\31-0.3582.hdf5
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3758 - accuracy: 0.8645 - val_loss: 0.3582 - val_accuracy: 0.8691
# Epoch 32/100
# 4459/4470 [============================>.] - ETA: 0s - loss: 0.3730 - accuracy: 0.8655
# Epoch 32: val_loss improved from 0.35824 to 0.35549, saving model to ./model\32-0.3555.hdf5
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3730 - accuracy: 0.8654 - val_loss: 0.3555 - val_accuracy: 0.8743
# Epoch 33/100
# 4456/4470 [============================>.] - ETA: 0s - loss: 0.3800 - accuracy: 0.8636
# Epoch 33: val_loss did not improve from 0.35549
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3801 - accuracy: 0.8635 - val_loss: 0.3632 - val_accuracy: 0.8695
# Epoch 34/100
# 4469/4470 [============================>.] - ETA: 0s - loss: 0.3754 - accuracy: 0.8647
# Epoch 34: val_loss did not improve from 0.35549
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3754 - accuracy: 0.8647 - val_loss: 0.3735 - val_accuracy: 0.8642
# Epoch 35/100
# 4465/4470 [============================>.] - ETA: 0s - loss: 0.3727 - accuracy: 0.8650
# Epoch 35: val_loss did not improve from 0.35549
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3728 - accuracy: 0.8650 - val_loss: 0.4080 - val_accuracy: 0.8678
# Epoch 36/100
# 4453/4470 [============================>.] - ETA: 0s - loss: 0.3702 - accuracy: 0.8662
# Epoch 36: val_loss did not improve from 0.35549
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3702 - accuracy: 0.8662 - val_loss: 0.3909 - val_accuracy: 0.8667
# Epoch 37/100
# 4459/4470 [============================>.] - ETA: 0s - loss: 0.3797 - accuracy: 0.8634
# Epoch 37: val_loss did not improve from 0.35549
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3798 - accuracy: 0.8634 - val_loss: 0.3872 - val_accuracy: 0.8717
# Epoch 38/100
# 4457/4470 [============================>.] - ETA: 0s - loss: 0.3721 - accuracy: 0.8660
# Epoch 38: val_loss did not improve from 0.35549
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3723 - accuracy: 0.8660 - val_loss: 0.4218 - val_accuracy: 0.8506
# Epoch 39/100
# 4464/4470 [============================>.] - ETA: 0s - loss: 0.3791 - accuracy: 0.8638
# Epoch 39: val_loss did not improve from 0.35549
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3790 - accuracy: 0.8638 - val_loss: 0.3766 - val_accuracy: 0.8677
# Epoch 40/100
# 4465/4470 [============================>.] - ETA: 0s - loss: 0.3713 - accuracy: 0.8660
# Epoch 40: val_loss did not improve from 0.35549
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3713 - accuracy: 0.8660 - val_loss: 0.3763 - val_accuracy: 0.8705
# Epoch 41/100
# 4469/4470 [============================>.] - ETA: 0s - loss: 0.3731 - accuracy: 0.8658
# Epoch 41: val_loss did not improve from 0.35549
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3731 - accuracy: 0.8658 - val_loss: 0.3840 - val_accuracy: 0.8721
# Epoch 42/100
# 4465/4470 [============================>.] - ETA: 0s - loss: 0.3980 - accuracy: 0.8569
# Epoch 42: val_loss did not improve from 0.35549
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3979 - accuracy: 0.8570 - val_loss: 0.3707 - val_accuracy: 0.8715
# 5587/5587 [==============================] - 7s 1ms/step
# [[ 33475    573   8158]
#  [  1752  19293   4916]
#  [  6334    962 103318]]
# 0.8730569803278871
#               precision    recall  f1-score   support
#
#            0       0.81      0.79      0.80     42206
#            1       0.93      0.74      0.82     25961
#            2       0.89      0.93      0.91    110614
#
#     accuracy                           0.87    178781
#    macro avg       0.87      0.82      0.84    178781
# weighted avg       0.87      0.87      0.87    178781
#
# Epoch 1/100
# 4459/4470 [============================>.] - ETA: 0s - loss: 0.7377 - accuracy: 0.7576
# Epoch 1: val_loss did not improve from 0.35549
# 4470/4470 [==============================] - 17s 4ms/step - loss: 0.7373 - accuracy: 0.7576 - val_loss: 0.5047 - val_accuracy: 0.8079
# Epoch 2/100
# 4469/4470 [============================>.] - ETA: 0s - loss: 0.5068 - accuracy: 0.8124
# Epoch 2: val_loss did not improve from 0.35549
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.5068 - accuracy: 0.8124 - val_loss: 0.4462 - val_accuracy: 0.8357
# Epoch 3/100
# 4459/4470 [============================>.] - ETA: 0s - loss: 0.4616 - accuracy: 0.8312
# Epoch 3: val_loss did not improve from 0.35549
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.4615 - accuracy: 0.8312 - val_loss: 0.4272 - val_accuracy: 0.8435
# Epoch 4/100
# 4457/4470 [============================>.] - ETA: 0s - loss: 0.4387 - accuracy: 0.8403
# Epoch 4: val_loss did not improve from 0.35549
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.4388 - accuracy: 0.8403 - val_loss: 0.4059 - val_accuracy: 0.8515
# Epoch 5/100
# 4468/4470 [============================>.] - ETA: 0s - loss: 0.4262 - accuracy: 0.8455
# Epoch 5: val_loss did not improve from 0.35549
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.4262 - accuracy: 0.8455 - val_loss: 0.4105 - val_accuracy: 0.8530
# Epoch 6/100
# 4461/4470 [============================>.] - ETA: 0s - loss: 0.4166 - accuracy: 0.8491
# Epoch 6: val_loss did not improve from 0.35549
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.4165 - accuracy: 0.8491 - val_loss: 0.3883 - val_accuracy: 0.8598
# Epoch 7/100
# 4455/4470 [============================>.] - ETA: 0s - loss: 0.4098 - accuracy: 0.8518
# Epoch 7: val_loss did not improve from 0.35549
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.4098 - accuracy: 0.8517 - val_loss: 0.3865 - val_accuracy: 0.8582
# Epoch 8/100
# 4462/4470 [============================>.] - ETA: 0s - loss: 0.4053 - accuracy: 0.8534
# Epoch 8: val_loss did not improve from 0.35549
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.4053 - accuracy: 0.8534 - val_loss: 0.3749 - val_accuracy: 0.8612
# Epoch 9/100
# 4461/4470 [============================>.] - ETA: 0s - loss: 0.4017 - accuracy: 0.8551
# Epoch 9: val_loss did not improve from 0.35549
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.4016 - accuracy: 0.8551 - val_loss: 0.3857 - val_accuracy: 0.8599
# Epoch 10/100
# 4469/4470 [============================>.] - ETA: 0s - loss: 0.3968 - accuracy: 0.8570
# Epoch 10: val_loss did not improve from 0.35549
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3968 - accuracy: 0.8570 - val_loss: 0.3761 - val_accuracy: 0.8614
# Epoch 11/100
# 4460/4470 [============================>.] - ETA: 0s - loss: 0.3936 - accuracy: 0.8578
# Epoch 11: val_loss did not improve from 0.35549
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3936 - accuracy: 0.8578 - val_loss: 0.3945 - val_accuracy: 0.8567
# Epoch 12/100
# 4457/4470 [============================>.] - ETA: 0s - loss: 0.3911 - accuracy: 0.8590
# Epoch 12: val_loss did not improve from 0.35549
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3911 - accuracy: 0.8589 - val_loss: 0.3776 - val_accuracy: 0.8622
# Epoch 13/100
# 4458/4470 [============================>.] - ETA: 0s - loss: 0.3888 - accuracy: 0.8601
# Epoch 13: val_loss did not improve from 0.35549
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3888 - accuracy: 0.8602 - val_loss: 0.3762 - val_accuracy: 0.8644
# Epoch 14/100
# 4463/4470 [============================>.] - ETA: 0s - loss: 0.3856 - accuracy: 0.8614
# Epoch 14: val_loss did not improve from 0.35549
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3856 - accuracy: 0.8614 - val_loss: 0.3698 - val_accuracy: 0.8651
# Epoch 15/100
# 4468/4470 [============================>.] - ETA: 0s - loss: 0.3842 - accuracy: 0.8617
# Epoch 15: val_loss did not improve from 0.35549
# 4470/4470 [==============================] - 17s 4ms/step - loss: 0.3842 - accuracy: 0.8617 - val_loss: 0.3671 - val_accuracy: 0.8646
# Epoch 16/100
# 4462/4470 [============================>.] - ETA: 0s - loss: 0.3817 - accuracy: 0.8621
# Epoch 16: val_loss did not improve from 0.35549
# 4470/4470 [==============================] - 17s 4ms/step - loss: 0.3817 - accuracy: 0.8621 - val_loss: 0.3696 - val_accuracy: 0.8672
# Epoch 17/100
# 4459/4470 [============================>.] - ETA: 0s - loss: 0.3800 - accuracy: 0.8631
# Epoch 17: val_loss did not improve from 0.35549
# 4470/4470 [==============================] - 17s 4ms/step - loss: 0.3800 - accuracy: 0.8631 - val_loss: 0.3650 - val_accuracy: 0.8677
# Epoch 18/100
# 4465/4470 [============================>.] - ETA: 0s - loss: 0.3794 - accuracy: 0.8638
# Epoch 18: val_loss did not improve from 0.35549
# 4470/4470 [==============================] - 17s 4ms/step - loss: 0.3794 - accuracy: 0.8638 - val_loss: 0.3879 - val_accuracy: 0.8604
# Epoch 19/100
# 4463/4470 [============================>.] - ETA: 0s - loss: 0.3821 - accuracy: 0.8629
# Epoch 19: val_loss improved from 0.35549 to 0.34883, saving model to ./model\19-0.3488.hdf5
# 4470/4470 [==============================] - 17s 4ms/step - loss: 0.3821 - accuracy: 0.8629 - val_loss: 0.3488 - val_accuracy: 0.8706
# Epoch 20/100
# 4466/4470 [============================>.] - ETA: 0s - loss: 0.3770 - accuracy: 0.8645
# Epoch 20: val_loss did not improve from 0.34883
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3770 - accuracy: 0.8645 - val_loss: 0.3613 - val_accuracy: 0.8686
# Epoch 21/100
# 4470/4470 [==============================] - ETA: 0s - loss: 0.3774 - accuracy: 0.8646
# Epoch 21: val_loss did not improve from 0.34883
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3774 - accuracy: 0.8646 - val_loss: 0.3738 - val_accuracy: 0.8675
# Epoch 22/100
# 4453/4470 [============================>.] - ETA: 0s - loss: 0.3762 - accuracy: 0.8652
# Epoch 22: val_loss did not improve from 0.34883
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3763 - accuracy: 0.8652 - val_loss: 0.3644 - val_accuracy: 0.8697
# Epoch 23/100
# 4456/4470 [============================>.] - ETA: 0s - loss: 0.3751 - accuracy: 0.8658
# Epoch 23: val_loss did not improve from 0.34883
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3750 - accuracy: 0.8657 - val_loss: 0.3571 - val_accuracy: 0.8717
# Epoch 24/100
# 4468/4470 [============================>.] - ETA: 0s - loss: 0.3750 - accuracy: 0.8657
# Epoch 24: val_loss did not improve from 0.34883
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3750 - accuracy: 0.8657 - val_loss: 0.3665 - val_accuracy: 0.8674
# Epoch 25/100
# 4455/4470 [============================>.] - ETA: 0s - loss: 0.3723 - accuracy: 0.8661
# Epoch 25: val_loss did not improve from 0.34883
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3724 - accuracy: 0.8661 - val_loss: 0.3569 - val_accuracy: 0.8707
# Epoch 26/100
# 4461/4470 [============================>.] - ETA: 0s - loss: 0.3721 - accuracy: 0.8664
# Epoch 26: val_loss did not improve from 0.34883
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3721 - accuracy: 0.8664 - val_loss: 0.3492 - val_accuracy: 0.8734
# Epoch 27/100
# 4459/4470 [============================>.] - ETA: 0s - loss: 0.3704 - accuracy: 0.8668
# Epoch 27: val_loss did not improve from 0.34883
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3704 - accuracy: 0.8668 - val_loss: 0.3579 - val_accuracy: 0.8725
# Epoch 28/100
# 4465/4470 [============================>.] - ETA: 0s - loss: 0.3709 - accuracy: 0.8672
# Epoch 28: val_loss did not improve from 0.34883
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3709 - accuracy: 0.8672 - val_loss: 0.3508 - val_accuracy: 0.8737
# Epoch 29/100
# 4460/4470 [============================>.] - ETA: 0s - loss: 0.3680 - accuracy: 0.8680
# Epoch 29: val_loss did not improve from 0.34883
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3680 - accuracy: 0.8680 - val_loss: 0.3520 - val_accuracy: 0.8724
# 5587/5587 [==============================] - 7s 1ms/step
# [[ 32112    787   9307]
#  [  1478  19691   4792]
#  [  5093   1162 104359]]
# 0.8734820814292347
#               precision    recall  f1-score   support
#
#            0       0.83      0.76      0.79     42206
#            1       0.91      0.76      0.83     25961
#            2       0.88      0.94      0.91    110614
#
#     accuracy                           0.87    178781
#    macro avg       0.87      0.82      0.84    178781
# weighted avg       0.87      0.87      0.87    178781
#
# Epoch 1/100
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3888 - accuracy: 0.8588 - val_loss: 0.3662 - val_accuracy: 0.8667
# Epoch 13/100
# 4467/4470 [============================>.] - ETA: 0s - loss: 0.3874 - accuracy: 0.8599
# Epoch 13: val_loss did not improve from 0.34883
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3873 - accuracy: 0.8599 - val_loss: 0.3805 - val_accuracy: 0.8590
# Epoch 14/100
# 4465/4470 [============================>.] - ETA: 0s - loss: 0.3850 - accuracy: 0.8602
# Epoch 14: val_loss did not improve from 0.34883
# 4470/4470 [==============================] - 16s 3ms/step - loss: 0.3850 - accuracy: 0.8602 - val_loss: 0.3661 - val_accuracy: 0.8655
# Epoch 15/100
# 4465/4470 [============================>.] - ETA: 0s - loss: 0.3825 - accuracy: 0.8613
# Epoch 15: val_loss did not improve from 0.34883
# 4470/4470 [==============================] - 15s 3ms/step - loss: 0.3825 - accuracy: 0.8613 - val_loss: 0.3664 - val_accuracy: 0.8667
# Epoch 16/100
# 4468/4470 [============================>.] - ETA: 0s - loss: 0.3802 - accuracy: 0.8626
# Epoch 16: val_loss did not improve from 0.34883
# 4470/4470 [==============================] - 15s 3ms/step - loss: 0.3802 - accuracy: 0.8626 - val_loss: 0.3630 - val_accuracy: 0.8690
# Epoch 17/100
# 4464/4470 [============================>.] - ETA: 0s - loss: 0.3780 - accuracy: 0.8629
# Epoch 17: val_loss did not improve from 0.34883
# 4470/4470 [==============================] - 15s 3ms/step - loss: 0.3780 - accuracy: 0.8629 - val_loss: 0.3617 - val_accuracy: 0.8692
# Epoch 18/100
# 4450/4470 [============================>.] - ETA: 0s - loss: 0.3789 - accuracy: 0.8626
# Epoch 18: val_loss did not improve from 0.34883
# 4470/4470 [==============================] - 16s 3ms/step - loss: 0.3790 - accuracy: 0.8626 - val_loss: 0.3527 - val_accuracy: 0.8713
# Epoch 19/100
# 4464/4470 [============================>.] - ETA: 0s - loss: 0.3755 - accuracy: 0.8636
# Epoch 19: val_loss improved from 0.34883 to 0.34521, saving model to ./model\19-0.3452.hdf5
# 4470/4470 [==============================] - 15s 3ms/step - loss: 0.3755 - accuracy: 0.8636 - val_loss: 0.3452 - val_accuracy: 0.8736
# Epoch 20/100
# 4456/4470 [============================>.] - ETA: 0s - loss: 0.3762 - accuracy: 0.8634
# Epoch 20: val_loss did not improve from 0.34521
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3762 - accuracy: 0.8634 - val_loss: 0.3580 - val_accuracy: 0.8687
# Epoch 21/100
# 4461/4470 [============================>.] - ETA: 0s - loss: 0.3732 - accuracy: 0.8641
# Epoch 21: val_loss did not improve from 0.34521
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.3732 - accuracy: 0.8640 - val_loss: 0.3536 - val_accuracy: 0.8721
# Epoch 22/100
# 4465/4470 [============================>.] - ETA: 0s - loss: 0.3743 - accuracy: 0.8646
# Epoch 22: val_loss did not improve from 0.34521
# 4470/4470 [==============================] - 16s 3ms/step - loss: 0.3743 - accuracy: 0.8646 - val_loss: 0.3652 - val_accuracy: 0.8690
# Epoch 23/100
# 4469/4470 [============================>.] - ETA: 0s - loss: 0.3741 - accuracy: 0.8643
# Epoch 23: val_loss did not improve from 0.34521
# 4470/4470 [==============================] - 16s 3ms/step - loss: 0.3741 - accuracy: 0.8643 - val_loss: 0.4252 - val_accuracy: 0.8451
# Epoch 24/100
# 4460/4470 [============================>.] - ETA: 0s - loss: 0.3715 - accuracy: 0.8653
# Epoch 24: val_loss did not improve from 0.34521
# 4470/4470 [==============================] - 16s 4ms/step - loss: 0.
val_loss did not improve from 0.33364
# 4470/4470 [==============================] - 16s 3ms/step - loss: 0.4699 - accuracy: 0.8305 - val_loss: 0.4588 - val_accuracy: 0.8343
# Epoch 43/100
# 4467/4470 [============================>.] - ETA: 0s - loss: 0.4673 - accuracy: 0.8310
# Epoch 43: val_loss did not improve from 0.33364
# 4470/4470 [==============================] - 15s 3ms/step - loss: 0.4673 - accuracy: 0.8310 - val_loss: 0.4838 - val_accuracy: 0.8243
# Epoch 44/100
# 4454/4470 [============================>.] - ETA: 0s - loss: 0.4691 - accuracy: 0.8306
# Epoch 44: val_loss did not improve from 0.33364
# 4470/4470 [==============================] - 15s 3ms/step - loss: 0.4689 - accuracy: 0.8307 - val_loss: 0.4487 - val_accuracy: 0.8379
# Epoch 45/100
# 4467/4470 [============================>.] - ETA: 0s - loss: 0.4689 - accuracy: 0.8308
# Epoch 45: val_loss did not improve from 0.33364
# 4470/4470 [==============================] - 15s 3ms/step - loss: 0.4689 - accuracy: 0.8308 - val_loss: 0.4602 - val_accuracy: 0.8338
# Epoch 46/100
# 4463/4470 [============================>.] - ETA: 2s - loss: 0.4682 - accuracy: 0.8309
# Epoch 46: val_loss did not improve from 0.33364
# 4470/4470 [==============================] - 1613s 361ms/step - loss: 0.4681 - accuracy: 0.8309 - val_loss: 0.4533 - val_accuracy: 0.8361
# Epoch 47/100
# 4463/4470 [============================>.] - ETA: 0s - loss: 0.4644 - accuracy: 0.8327
# Epoch 47: val_loss did not improve from 0.33364
# 4470/4470 [==============================] - 12s 3ms/step - loss: 0.4644 - accuracy: 0.8327 - val_loss: 0.4619 - val_accuracy: 0.8326
# 5587/5587 [==============================] - 6s 1ms/step
# [[32008  1249  8949]
#  [ 1862 17869  6230]
#  [ 9513  1956 99145]]
# 0.8335449516447497
#               precision    recall  f1-score   support
#
#            0       0.74      0.76      0.75     42206
#            1       0.85      0.69      0.76     25961
#            2       0.87      0.90      0.88    110614
#
#     accuracy                           0.83    178781
#    macro avg       0.82      0.78      0.80    178781
# weighted avg       0.83      0.83      0.83    178781

# %% [markdown]
# ## **4. 추론 (Inference)**
#
# 훈련시킨 모델을 직접 사용해보고자 한다. 잘 훈련된 모델이라면 버스 승객의 승하차 영상을 입력 데이터로 주었을 때, 승하차 여부를 결과값으로 모델이 내보낼 것이다. 그 과정을 진행해보고자 한다.

# %%
import cv2
import numpy as np
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras.models import load_model

# %%
hub_model = hub.load('https://tfhub.dev/google/movenet/multipose/lightning/1')
movenet = hub_model.signatures['serving_default']

# %%
# main - 승하차
cap = cv2.VideoCapture('C:/Users/USER/project/movenet/버스승차영상.mp4')

get_state = ['get_on', 'get_off', 'nothing']

while cap.isOpened():
    ret, frame = cap.read()
    point_list = []
    
    if (ret): # frame capture 결과
        # frame = cv2.flip(frame,0) # 영상 뒤집혀서 출력되는 경우 사용
        img = frame.copy()
        img = tf.image.resize_with_pad(tf.expand_dims(img, axis=0), 192, 256)
        input_img = tf.cast(img, dtype=tf.int32)

        results = movenet(input_img)
        keypoints_with_scores = results['output_0'].numpy()[:,:,:51].reshape((6, 17, 3))

        loop_through_people(frame, keypoints_with_scores, EDGES, 0.2)

        # load model
        model = load_model('C:/Users/USER/project/movenet/19-0.3527(승하차CNN).hdf5')

        for point in point_list:
            if len(point) == 17: # keypoints가 다 잡혔을 때 결과값 예측
                # train model에 들어간 keypoints랑 movenet에 검출되는 keypoints 순서가 달라서 변환
                switch = [point[16], point[14], point[12], point[11], point[13], point[15], point[4], point[0], point[2], point[1],
                        point[10], point[8], point[6], point[5], point[7], point[9]]
                result = model.predict(np.array(switch).reshape(-1,16,1,3))
                cv2.putText(frame, get_state[result.argmax()], (point[0][0]-100, point[0][1]-100), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 0, 0), 2, lineType=cv2.LINE_AA)
                print(get_state[result.argmax()])
        cv2.imshow('', frame)
            
        if cv2.waitKey(1) & 0xFF==ord('q'):
            break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 51ms/step
# get_off
# 1/1 [==============================] - 0s 50ms/step
# get_off
# 1/1 [==============================] - 0s 38ms/step
# get_on
# 1/1 [==============================] - 0s 45ms/step
# nothing
# 1/1 [==============================] - 0s 47ms/step
# get_on
# 1/1 [==============================] - 0s 46ms/step
# get_on
# 1/1 [==============================] - 0s 48ms/step
# get_on
# 1/1 [==============================] - 0s 46ms/step
# get_on
# 1/1 [==============================] - 0s 47ms/step
# get_on
# 1/1 [==============================] - 0s 49ms/step
# get_on
# 1/1 [==============================] - 0s 46ms/step
# get_on
# 1/1 [==============================] - 0s 48ms/step
# get_on
# 1/1 [==============================] - 0s 45ms/step
# nothing
# 1/1 [==============================] - 0s 46ms/step
# nothing
# 1/1 [==============================] - 0s 46ms/step
# nothing
# 1/1 [==============================] - 0s 45ms/step
# nothing
# 1/1 [==============================] - 0s 47ms/step
# nothing
# 1/1 [==============================] - 0s 46ms/step
# nothing

# %%
EDGES = {
    (0, 1): 'm',
    (0, 2): 'c',
    (1, 3): 'm',
    (2, 4): 'c',
    (0, 5): 'm',
    (0, 6): 'c',
    (5, 7): 'm',
    (7, 9): 'm',
    (6, 8): 'c',
    (8, 10): 'c',
    (5, 6): 'y',
    (5, 11): 'm',
    (6, 12): 'c',
    (11, 12): 'y',
    (11, 13): 'm',
    (13, 15): 'm',
    (12, 14): 'c',
    (14, 16): 'c'
}

# %%
def loop_through_people(frame, keypoints_with_scores, edges, confidence_threshold):
    for person in keypoints_with_scores:
        draw_lines(frame, person, edges, confidence_threshold)
        draw_keypoints(frame, person, confidence_threshold)

# %%
def draw_lines(frame, keypoints, edges, confidence_threshold):
    y, x, _ = frame.shape
    shaped = np.squeeze(np.multiply(keypoints, [y,x,1]))
    
    for edge, _ in edges.items():
        p1, p2 = edge
        y1, x1, c1 = shaped[p1]
        y2, x2, c2 = shaped[p2]
        
        if (c1 > confidence_threshold) & (c2 > confidence_threshold):      
            cv2.line(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 0, 255), 2)

# %%
def draw_keypoints(frame, keypoints, confidence_threshold):
    y, x, _ = frame.shape
    shaped = np.squeeze(np.multiply(keypoints, [y,x,1]))

    i = 0
    points = []

    for kp in shaped:
        ky, kx, kp_conf = kp
        if kp_conf > confidence_threshold:
            cv2.circle(frame, (int(kx), int(ky)), 4, (0, 255, 0), -1)
            
            if i == 0:
                point_list.append(points)
            points.append((int(kx), int(ky), 0))
            i += 1
